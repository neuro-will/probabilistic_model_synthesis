# %% [markdown]
# A notebook where we synthesize regression models across conditions.  We examine the performance of the models when they are fit together and individually.
#
# Specifically, we synthesize regression models that predict only one variable.  The models project data down to a single variable, which is then passed through a complicated non-linear function.  When we say we synthesize models "across conditions" we mean that we simulate data so that data for each model projects into a given range of the low-s space, so we only see the behavior of the non-linear function in a certain range for each individual.
#
# Some details:
#
# 1) Each input variable in the model is associated with a 2-d position (position is the measurable property in this example).  Variable positions are sampled uniformly from the unit square.
#
# 2) We pull the weights for each model from a prior where the mean and std. conditioned on position are sums of bump functions (so they are truly smooth). When fitting models, we use hypercube functions for the mean and std. (so there
# is model mismatch here).  This can make correctly learning the std functions tricky, because if the true mean functions vary alot within a single hypercube, we will learn a standard deviation that is elevated in that region
#
# 3) We simulate data with scales and biases which are very close to 1 and 0, respectively.  This keeps things simpler.  When fitting, we use priors which assume scales and biases are concentrated near these values.
#
# 4) We pull noise variances from a Gamma distribution when simulating data, and we also fit models with priors and posteriors which are also Gamma distributions over noise variances.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import copy
import math

import matplotlib
from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg
import torch

from janelia_core.math.basic_functions import list_grid_pts
from janelia_core.ml.extra_torch_modules import DenseLNLNet
from janelia_core.ml.extra_torch_modules import QuadSurf
from janelia_core.ml.utils import list_torch_devices


from probabilistic_model_synthesis.gaussian_nonlinear_regression import compare_weight_prior_dists
from probabilistic_model_synthesis.gaussian_nonlinear_regression import align_low_d_spaces
from probabilistic_model_synthesis.gaussian_nonlinear_regression import fit_with_hypercube_priors
from probabilistic_model_synthesis.gaussian_nonlinear_regression import Fitter
from probabilistic_model_synthesis.gaussian_nonlinear_regression import generate_hypercube_prior_collection
from probabilistic_model_synthesis.gaussian_nonlinear_regression import GNLRMdl
from probabilistic_model_synthesis.simulation import generate_sum_of_bump_fcns_dist
from probabilistic_model_synthesis.simulation import sample_proj_data_from_interval
from probabilistic_model_synthesis.visualization import assign_colors_to_pts
from probabilistic_model_synthesis.visualization import plot_three_dim_pts

# %%
# %matplotlib notebook
plt.style.use('dark_background')
matplotlib.rcParams.update({'font.size': 20})

# %% [markdown]
# ## Parameters go here

# %%
# Range of the number of input variables we observe from each individual - the actual number of variables we 
# observe from an individual will be pulled uniformly from this range (inclusive)
n_input_var_range = [5000, 5100]

# Range of the number of samples we observe from each individual - the actual number we observe from each individual
# will be unformly from this range (inclusive)
n_smps_range = [12000, 15000]

# ===============================================================================================
# Parameters for the true priors 

# Options for the prior distribution on weights
true_w_prior_opts = {'n_bump_fcns': 50, 'd_in': 2, 'p': 1, 'mn_m_std': 1.0, 'std_m_std': .1, 'bump_w': .2}

# Options for the prior distributions on the scales, biases and psi
true_s_in_prior_opts = {'mn_mn': 1.0/np.sqrt(n_input_var_range[0]), 'mn_std': .00000001, 
                     'std_iv': .00001, 'std_lb': .0000001}

true_s_out_prior_opts = {'mn_mn': 1.0, 'mn_std': .00000001, 
                     'std_iv': .00001, 'std_lb': .0000001}

true_b_prior_opts = {'mn_mn': 0.0, 'mn_std': .00000001, 'std_iv': .001}
true_psi_prior_opts = {'conc_iv': 10.0, 'rate_iv': 1000.0, 'rate_ub': 10000.0}

# ===============================================================================================
# Parameters for the fit models

# The full options for setting up the prior on weights
fit_hc_params = {'n_divisions_per_dim': [20, 20], 
                 'dim_ranges': np.asarray([[-.1, 1.1],
                                       [-.1, 1.1]]),
                 'n_div_per_hc_side_per_dim': [1, 1]}

# The full options for setting up the prior on weights
fit_w_prior_opts = {'mn_hc_params': fit_hc_params, 'std_hc_params': fit_hc_params, 
                     'min_std': .000001, 'mn_init': 0.0, 'std_init': .3}

# Options for the prior distributions on the scales, biases and psi
fit_s_in_prior_opts = true_s_in_prior_opts
fit_s_out_prior_opts = true_s_out_prior_opts
fit_b_prior_opts = true_b_prior_opts
fit_psi_prior_opts = true_psi_prior_opts

# Options for posterior distribtions 
s_in_post_opts = {'mn_mn': 1.0/np.sqrt(n_input_var_range[0]), 'mn_std': .000001, 
               'std_iv': .00001, 'std_lb': .0000001}
s_out_post_opts = {'mn_mn': 1.0, 'mn_std': .000001, 
               'std_iv': .00001, 'std_lb': .0000001}

b_post_opts = {'mn_mn': 0.0, 'mn_std': .01}
psi_post_opts = {'conc_iv': 10.0, 'rate_iv': 1.0, 'rate_ub': 100000.0}

# Options for the densenet which makes up the shared-m module
dense_net_opts = {'n_layers': 10, 'growth_rate': 5, 'bias': True}

# ======================================================================================================
# Parameters for fitting - should be entered as lists, each entry corresponding to one round of fitting

# Parameters when fitting combined models
comb_sp_fit_opts = [{'n_epochs': 100, 'milestones': None, 'update_int': 100, 'init_lr': .1}]
comb_ip_fit_opts = [{'n_epochs': 5000, 'milestones': [500], 'update_int': 100, 'init_lr': .1}]

single_sp_fit_opts = [{'n_epochs': 100, 'milestones': None, 'update_int': 100, 'init_lr': .1}]
single_ip_fit_opts = [{'n_epochs': 5000, 'milestones': [500], 'update_int': 100, 'init_lr': .1}]


# ======================================================================================================
# Specify the number of intermediate variables and number of variables we predict
p = 1
d_pred = 1

# %% [markdown]
# ## Create true distributions that govern how systems under study are generated

# %%
# Because we do not use the hypercube priors on weights, we provide some default paramaters for these before
# creating the priors

temp_hc_params = {'n_divisions_per_dim': [10, 10], 
                  'dim_ranges': np.asarray([[-.1, 1.1],
                                       [-.1, 1.1]]),
                   'n_div_per_hc_side_per_dim': [1, 1]}

temp_w_prior_opts = {'mn_hc_params': temp_hc_params, 'std_hc_params': temp_hc_params, 
                     'min_std': .000001, 'mn_init': 0.0, 'std_init': .3}

true_priors = generate_hypercube_prior_collection(p=p, d_pred=d_pred, 
                                                  w_prior_opts=temp_w_prior_opts, 
                                                  s_in_prior_opts=true_s_in_prior_opts, 
                                                  b_in_prior_opts=true_b_prior_opts, 
                                                  s_out_prior_opts=true_s_out_prior_opts,
                                                  b_out_prior_opts=true_b_prior_opts, 
                                                  psi_prior_opts=true_psi_prior_opts)

# We replace the prior over weights 
true_priors.w_prior = generate_sum_of_bump_fcns_dist(**true_w_prior_opts)

# %% [markdown]
# ## Define the true non-linear function relating projections of input variables to the mean of output variables

# %%
class Quad(torch.nn.Module):
    
    def forward(self, x):
        return x + torch.sin(3*x)

# %%
m_true = Quad()

# %% [markdown]
# ## Generate data

# %% [markdown]
# ### Generate properties

# %%
n_individuals = 4
ind_n_vars = np.random.randint(n_input_var_range[0], n_input_var_range[1]+1, n_individuals)
ind_props = [torch.rand(size=[n_vars,2]) for n_vars in ind_n_vars]

# %% [markdown]
# ### Generate true models for each individual

# %%
with torch.no_grad():
    ind_true_mdls = [GNLRMdl(m=m_true, 
                     w=true_priors.w_prior.form_standard_sample(true_priors.w_prior.sample(props)),
                     s_in=true_priors.s_in_prior.form_standard_sample(true_priors.s_in_prior.sample(props)).squeeze(axis=1),
                     b_in=true_priors.b_in_prior.form_standard_sample(true_priors.b_in_prior.sample(props)).squeeze(axis=1),
                     s_out=true_priors.s_out_prior.form_standard_sample(true_priors.s_out_prior.sample(props)).squeeze(axis=1),
                     b_out=true_priors.b_out_prior.form_standard_sample(true_priors.b_out_prior.sample(props)).squeeze(axis=1),
                     psi=true_priors.psi_prior.form_standard_sample(true_priors.psi_prior.sample(props)).squeeze(axis=1))
                     for props in ind_props]
    
    if d_pred > 1:
        for mdl in ind_true_mdls:
            mdl.s_out.data = mdl.s_out.data.squeeze()
            mdl.b_out.data = mdl.b_out.data.squeeze()
            mdl.psi.data = mdl.psi.data.squeeze()

# %% [markdown]
# ### Generate observations from true models

# %%
ind_n_smps = np.random.randint(n_smps_range[0], n_smps_range[1]+1, n_individuals)
ind_data = [None]*n_individuals

intervals = 1.96*np.sqrt(n_input_var_range[0])*np.linspace(-1, 1, n_individuals+1)

for i in range(n_individuals):
    x_i = torch.tensor(sample_proj_data_from_interval(n_smps=ind_n_smps[i], 
                                                      w=ind_true_mdls[i].w.detach().numpy(), 
                                                      interval=[intervals[i], intervals[i+1]]),
                       dtype=torch.float)
    with torch.no_grad():
        y_i = ind_true_mdls[i].sample(x=x_i)
    ind_data[i] = (x_i, y_i)
    
    print('Done generating data for individual ' + str(i) + '.')
# Out:
# Done generating data for individual 0.
# Done generating data for individual 1.
# Done generating data for individual 2.
# Done generating data for individual 3.

# %% [markdown]
# ## Synthesize models (fit models to the data together)

# %%
comb_fit_rs = fit_with_hypercube_priors(data=ind_data, props=ind_props, p=p, 
                                   w_prior_opts=fit_w_prior_opts, 
                                   s_in_prior_opts=fit_s_in_prior_opts,
                                   b_in_prior_opts=fit_b_prior_opts,
                                   s_out_prior_opts=fit_s_out_prior_opts,
                                   b_out_prior_opts=fit_b_prior_opts,
                                   psi_prior_opts=fit_psi_prior_opts,
                                   s_in_post_opts=s_in_post_opts,
                                   b_in_post_opts=b_post_opts,
                                   s_out_post_opts=s_out_post_opts,
                                   b_out_post_opts=b_post_opts,
                                   psi_post_opts=psi_post_opts,
                                   dense_net_opts=dense_net_opts, 
                                   sp_fit_opts=comb_sp_fit_opts, 
                                   ip_fit_opts=comb_ip_fit_opts)
# Out:
# Found 1 GPUs
# Beginning SP fitting.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.03e+08
# ----------------------------------------
# NELL: 4.42e+04, 3.76e+04, 3.27e+04, 3.09e+04
# W KL: 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00
# S_in KL: 2.53e+07, 2.53e+07, 2.53e+07, 2.53e+07
# B_in KL: 2.40e+03, 2.22e+03, 2.07e+03, 2.52e+03
# S_out KL: 2.53e+07, 2.53e+07, 2.53e+07, 2.53e+07
# B_out KL: 2.44e+03, 2.38e+03, 2.00e+03, 2.43e+03
# Psi KL: 7.78e+03, 7.78e+03, 7.78e+03, 7.78e+03
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.34931445121765137
# ----------------------------------------
# CPU cur memory used (GB): 3.57e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
# Beginning IP fitting.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.13e+08
# ----------------------------------------
# NELL: 2.36e+06, 4.93e+04, 2.25e+05, 7.85e+06
# W KL: 4.64e+04, 4.76e+04, 4.70e+04, 4.63e+04
# S_in KL: 2.52e+07, 2.53e+07, 2.53e+07, 2.53e+07
# B_in KL: 2.23e+03, 1.26e+03, 1.30e+03, 2.47e+03
# S_out KL: 2.53e+07, 2.53e+07, 2.53e+07, 2.53e+07
# B_out KL: 1.98e+03, 1.64e+03, 1.50e+03, 2.81e+03
# Psi KL: 4.31e+00, 2.44e+00, 4.62e+00, 4.26e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.11733651161193848
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 100 COMPLETE ===========
# Obj: 4.35e+04
# ----------------------------------------
# NELL: 7.53e+03, 8.31e+03, 5.48e+03, 1.06e+04
# W KL: 2.40e+02, 4.42e+03, 4.74e+03, 1.49e+03
# S_in KL: 2.45e+00, 8.65e+00, 1.38e+02, 3.10e+00
# B_in KL: 1.66e+01, 4.98e+01, 2.82e+02, 2.05e+01
# S_out KL: 1.40e-02, 1.06e-02, 2.41e-02, 8.10e-03
# B_out KL: 5.63e+00, 1.67e+01, 4.47e+01, 2.65e+01
# Psi KL: 9.16e-01, 1.04e+00, 9.60e-01, 8.83e-01
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 11.314745903015137
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 200 COMPLETE ===========
# Obj: 3.10e+04
# ----------------------------------------
# NELL: 5.26e+03, 2.16e+03, 2.89e+03, 7.52e+03
# W KL: 1.14e+03, 5.34e+03, 5.33e+03, 2.78e+02
# S_in KL: 1.10e+00, 5.26e+01, 5.83e+01, 5.07e+00
# B_in KL: 9.72e+01, 9.96e+01, 2.48e+02, 4.30e+01
# S_out KL: 2.25e-04, 6.74e-02, 4.12e-02, 6.66e-03
# B_out KL: 1.27e+01, 2.68e+02, 1.41e+02, 2.20e+01
# Psi KL: 4.81e-01, 1.17e+00, 8.35e-01, 1.46e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 22.318241357803345
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 300 COMPLETE ===========
# Obj: 2.54e+04
# ----------------------------------------
# NELL: -1.41e+03, 6.81e+02, 1.73e+03, 5.56e+03
# W KL: 3.80e+03, 5.89e+03, 6.48e+03, 4.24e+02
# S_in KL: 2.94e+01, 3.55e+02, 2.23e+01, 1.22e+01
# B_in KL: 6.67e+01, 4.90e+02, 4.31e+02, 3.86e+01
# S_out KL: 1.74e-02, 3.90e-02, 1.04e-02, 9.25e-03
# B_out KL: 1.34e+02, 5.71e+02, 3.70e+01, 1.79e+01
# Psi KL: 6.13e-01, 1.26e+00, 6.30e-01, 1.38e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 33.33630704879761
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 400 COMPLETE ===========
# Obj: 2.52e+04
# ----------------------------------------
# NELL: 6.49e+02, 5.64e+02, 1.89e+02, 2.63e+03
# W KL: 4.39e+03, 5.47e+03, 5.51e+03, 8.88e+02
# S_in KL: 3.22e+03, 2.11e+02, 1.79e+02, 1.45e+01
# B_in KL: 1.09e+00, 1.73e+02, 2.07e+01, 5.62e+01
# S_out KL: 6.77e-01, 4.81e-01, 4.55e-02, 5.47e-03
# B_out KL: 9.23e+01, 5.63e+02, 3.34e+02, 4.27e+01
# Psi KL: 7.21e-01, 1.13e+00, 5.43e-01, 7.84e-01
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 44.373291969299316
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 500 COMPLETE ===========
# Obj: 1.49e+04
# ----------------------------------------
# NELL: -2.89e+03, -8.23e+02, -1.07e+03, 1.41e+03
# W KL: 3.46e+03, 6.49e+03, 6.18e+03, 1.22e+03
# S_in KL: 2.34e+00, 2.22e+02, 1.23e+01, 1.89e+01
# B_in KL: 4.86e+01, 1.53e+02, 1.36e+02, 4.31e+01
# S_out KL: 1.22e-01, 4.61e-01, 8.83e-01, 2.51e-01
# B_out KL: 2.72e+01, 8.53e+01, 1.48e+02, 2.67e+00
# Psi KL: 2.51e-01, 1.06e+00, 5.14e-01, 8.81e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 55.394765853881836
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 600 COMPLETE ===========
# Obj: 1.78e+03
# ----------------------------------------
# NELL: -3.98e+03, -8.58e+03, -7.52e+03, 9.41e+02
# W KL: 3.46e+03, 8.20e+03, 7.78e+03, 1.11e+03
# S_in KL: 1.22e+01, 1.74e+01, 1.44e+01, 9.09e+00
# B_in KL: 2.77e+01, 6.38e+01, 7.65e+01, 3.39e+01
# S_out KL: 2.38e-03, 3.48e-03, 1.80e-04, 2.38e-03
# B_out KL: 1.72e+01, 3.83e+01, 3.30e+01, 1.25e+01
# Psi KL: 2.90e-01, 1.87e+00, 1.10e+00, 1.35e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 66.50700998306274
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 700 COMPLETE ===========
# Obj: 2.26e+03
# ----------------------------------------
# NELL: -4.42e+03, -9.39e+03, -9.02e+03, 1.98e+03
# W KL: 3.88e+03, 8.87e+03, 8.78e+03, 1.20e+03
# S_in KL: 1.58e+01, 1.59e+01, 2.06e+01, 5.92e+00
# B_in KL: 3.01e+01, 6.18e+01, 4.48e+01, 5.35e+01
# S_out KL: 1.46e-03, 1.38e-03, 2.61e-04, 4.68e-04
# B_out KL: 1.54e+01, 3.81e+01, 5.39e+01, 2.19e+01
# Psi KL: 3.91e-01, 1.82e+00, 1.20e+00, 1.25e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 78.03291988372803
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 800 COMPLETE ===========
# Obj: -2.02e+02
# ----------------------------------------
# NELL: -6.76e+03, -9.59e+03, -1.01e+04, 2.12e+03
# W KL: 4.31e+03, 9.00e+03, 9.09e+03, 1.45e+03
# S_in KL: 2.28e+01, 9.93e-01, 8.73e+00, 1.00e+01
# B_in KL: 2.37e+01, 6.26e+01, 6.04e+01, 3.31e+01
# S_out KL: 4.90e-03, 1.62e-03, 3.60e-03, 1.48e-03
# B_out KL: 1.34e+01, 3.16e+01, 3.08e+01, 1.11e+01
# Psi KL: 4.30e-01, 1.88e+00, 1.20e+00, 1.21e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 89.59267497062683
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 900 COMPLETE ===========
# Obj: -7.04e+02
# ----------------------------------------
# NELL: -7.52e+03, -9.80e+03, -9.96e+03, 1.26e+03
# W KL: 4.89e+03, 9.13e+03, 9.26e+03, 1.62e+03
# S_in KL: 3.75e+01, 2.04e+01, 5.92e+00, 2.75e+01
# B_in KL: 2.89e+01, 6.05e+01, 6.77e+01, 4.14e+01
# S_out KL: 1.62e-03, 5.22e-03, 1.67e-02, 2.25e-03
# B_out KL: 1.64e+01, 4.55e+01, 2.87e+01, 1.46e+01
# Psi KL: 4.47e-01, 1.77e+00, 1.24e+00, 1.24e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 101.1003360748291
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 1000 COMPLETE ===========
# Obj: -1.98e+03
# ----------------------------------------
# NELL: -8.18e+03, -9.75e+03, -1.06e+04, -7.43e+01
# W KL: 5.91e+03, 9.12e+03, 9.40e+03, 1.83e+03
# S_in KL: 4.46e+01, 2.21e+00, 3.41e+01, 9.49e+00
# B_in KL: 1.72e+01, 5.11e+01, 4.36e+01, 3.90e+01
# S_out KL: 6.88e-03, 2.38e-03, 7.20e-03, 4.44e-03
# B_out KL: 8.98e+00, 2.33e+01, 4.94e+01, 1.59e+01
# Psi KL: 4.65e-01, 1.79e+00, 1.19e+00, 1.22e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 112.54103779792786
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 1100 COMPLETE ===========
# Obj: -2.71e+03
# ----------------------------------------
# NELL: -8.89e+03, -9.88e+03, -1.04e+04, -4.90e+02
# W KL: 6.05e+03, 9.18e+03, 9.44e+03, 2.00e+03
# S_in KL: 2.05e+01, 6.85e+00, 1.37e+01, 3.66e+00
# B_in KL: 8.54e+00, 5.44e+01, 4.05e+01, 3.51e+01
# S_out KL: 4.77e-04, 8.99e-03, 2.68e-02, 7.20e-05
# B_out KL: 1.29e+01, 1.83e+01, 4.74e+01, 1.59e+01
# Psi KL: 4.82e-01, 1.75e+00, 1.19e+00, 1.21e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 124.0435516834259
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
# =========== EPOCH 1200 COMPLETE ===========
# Obj: -4.06e+03
# ----------------------------------------
# NELL: -1.06e+04, -9.81e+03, -1.00e+04, -1.17e+03
# W KL: 6.38e+03, 9.11e+03, 9.42e+03, 2.27e+03
# S_in KL: 5.38e+00, 2.44e+01, 3.12e+01, 1.45e+01
# B_in KL: 3.19e+01, 6.13e+01, 2.95e+01, 3.74e+01
# S_out KL: 7.38e-03, 6.31e-02, 2.16e-02, 3.60e-03
# B_out KL: 1.11e+01, 3.49e+01, 2.45e+01, 1.03e+01
# Psi KL: 4.70e-01, 1.73e+00, 1.20e+00, 1.20e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 135.5190622806549
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 1300 COMPLETE ===========
# Obj: -3.64e+03
# ----------------------------------------
# NELL: -9.54e+03, -1.01e+04, -1.10e+04, -1.45e+03
# W KL: 6.72e+03, 9.17e+03, 9.46e+03, 2.49e+03
# S_in KL: 3.05e+02, 1.02e+01, 2.44e+00, 4.80e-01
# B_in KL: 5.47e+01, 4.78e+01, 5.49e+01, 2.57e+01
# S_out KL: 3.11e-03, 1.37e-02, 3.33e-02, 9.00e-04
# B_out KL: 1.04e+01, 6.01e+01, 2.43e+01, 1.08e+01
# Psi KL: 4.61e-01, 1.69e+00, 1.18e+00, 1.13e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 146.93821239471436
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 1400 COMPLETE ===========
# Obj: -5.35e+03
# ----------------------------------------
# NELL: -1.06e+04, -1.00e+04, -1.08e+04, -2.29e+03
# W KL: 6.45e+03, 9.16e+03, 9.47e+03, 2.95e+03
# S_in KL: 2.49e+01, 1.47e+00, 6.87e+01, 2.21e+01
# B_in KL: 1.78e+01, 6.28e+01, 5.74e+01, 3.36e+01
# S_out KL: 7.14e-03, 6.12e-03, 3.94e-03, 1.23e-02
# B_out KL: 8.46e+00, 2.78e+01, 4.67e+01, 1.62e+01
# Psi KL: 3.80e-01, 1.69e+00, 1.17e+00, 1.11e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 158.40247321128845
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 1500 COMPLETE ===========
# Obj: -3.42e+03
# ----------------------------------------
# NELL: -8.52e+03, -1.03e+04, -1.10e+04, -3.20e+03
# W KL: 6.80e+03, 9.19e+03, 9.57e+03, 2.98e+03
# S_in KL: 7.57e+02, 9.47e+00, 2.87e+00, 9.83e+00
# B_in KL: 1.49e+01, 5.47e+01, 3.37e+01, 2.54e+01
# S_out KL: 1.65e-02, 6.41e-02, 4.34e-02, 6.56e-03
# B_out KL: 1.28e+01, 2.70e+01, 2.70e+01, 1.01e+01
# Psi KL: 3.80e-01, 1.73e+00, 1.17e+00, 1.08e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 169.8503439426422
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 1600 COMPLETE ===========
# Obj: -4.59e+03
# ----------------------------------------
# NELL: -1.05e+04, -9.87e+03, -1.06e+04, -3.93e+03
# W KL: 7.20e+03, 9.24e+03, 9.66e+03, 3.77e+03
# S_in KL: 8.49e+01, 5.15e-01, 1.10e+02, 8.50e+00
# B_in KL: 1.92e+01, 4.44e+01, 2.86e+01, 2.41e+01
# S_out KL: 1.49e-01, 4.33e-02, 3.37e-02, 3.59e-02
# B_out KL: 1.21e+01, 2.43e+01, 2.37e+01, 2.05e+01
# Psi KL: 3.69e-01, 1.65e+00, 1.08e+00, 1.06e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 181.16097450256348
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 1700 COMPLETE ===========
# Obj: -6.22e+03
# ----------------------------------------
# NELL: -9.60e+03, -1.02e+04, -1.10e+04, -4.65e+03
# W KL: 6.07e+03, 9.19e+03, 9.57e+03, 3.73e+03
# S_in KL: 2.41e+02, 3.98e+01, 8.33e+01, 7.07e+00
# B_in KL: 2.64e+01, 4.87e+01, 3.71e+01, 4.09e+01
# S_out KL: 1.80e-04, 7.20e-05, 1.50e-03, 2.88e-04
# B_out KL: 1.24e+01, 3.06e+01, 5.56e+01, 1.47e+01
# Psi KL: 2.23e-01, 1.60e+00, 1.18e+00, 9.33e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 192.50947523117065
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 1800 COMPLETE ===========
# Obj: -5.86e+03
# ----------------------------------------
# NELL: -9.73e+03, -1.04e+04, -1.09e+04, -4.02e+03
# W KL: 6.16e+03, 9.27e+03, 9.66e+03, 3.75e+03
# S_in KL: 5.57e+01, 5.46e+00, 1.67e+01, 2.20e+01
# B_in KL: 2.35e+01, 6.14e+01, 5.63e+01, 1.63e+01
# S_out KL: 3.95e-03, 9.54e-02, 2.66e-02, 1.10e-03
# B_out KL: 9.55e+00, 3.00e+01, 2.70e+01, 8.06e+00
# Psi KL: 1.74e-01, 1.53e+00, 1.12e+00, 7.62e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 203.88851141929626
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 1900 COMPLETE ===========
# Obj: -4.09e+03
# ----------------------------------------
# NELL: -9.78e+03, -1.04e+04, -1.08e+04, -2.23e+03
# W KL: 5.70e+03, 9.22e+03, 9.69e+03, 4.20e+03
# S_in KL: 5.55e-01, 9.08e+00, 4.24e+01, 8.60e+01
# B_in KL: 2.18e+01, 4.34e+01, 3.06e+01, 2.38e+01
# S_out KL: 9.25e-03, 6.93e-02, 2.08e-02, 9.00e-04
# B_out KL: 4.85e+00, 2.39e+01, 2.00e+01, 9.84e+00
# Psi KL: 1.62e-01, 1.57e+00, 1.10e+00, 6.99e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 215.23193168640137
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 2000 COMPLETE ===========
# Obj: 1.28e+04
# ----------------------------------------
# NELL: -3.97e+03, -8.78e+03, -8.87e+03, -8.30e+02
# W KL: 6.27e+03, 9.05e+03, 9.48e+03, 4.85e+03
# S_in KL: 4.35e+03, 2.59e+02, 3.71e+01, 3.01e+02
# B_in KL: 2.82e+02, 8.54e+00, 8.06e+01, 1.32e+02
# S_out KL: 6.15e-01, 6.29e+00, 1.52e+01, 6.46e+00
# B_out KL: 5.45e+00, 1.53e+00, 6.42e+01, 8.41e+00
# Psi KL: 1.00e-01, 1.27e+00, 8.51e-01, 1.65e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 226.62979936599731
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 2100 COMPLETE ===========
# Obj: 1.33e+04
# ----------------------------------------
# NELL: -8.88e+02, -9.57e+03, -1.09e+04, -4.91e+03
# W KL: 6.13e+03, 9.26e+03, 9.59e+03, 4.64e+03
# S_in KL: 9.18e+03, 1.34e+00, 1.78e+01, 3.72e+02
# B_in KL: 2.63e+01, 6.00e+01, 5.94e+01, 1.22e+01
# S_out KL: 8.69e-02, 1.53e-01, 3.42e-02, 3.89e-02
# B_out KL: 1.26e+02, 5.91e+01, 2.89e+01, 9.44e+00
# Psi KL: 1.60e-01, 1.53e+00, 1.18e+00, 7.49e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 237.90549302101135
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 2200 COMPLETE ===========
# Obj: -6.86e+03
# ----------------------------------------
# NELL: -1.04e+04, -1.04e+04, -1.14e+04, -4.80e+03
# W KL: 6.49e+03, 9.31e+03, 9.71e+03, 4.16e+03
# S_in KL: 6.20e+00, 2.53e+00, 4.92e+01, 1.43e+02
# B_in KL: 2.30e+01, 4.69e+01, 5.99e+01, 9.49e+00
# S_out KL: 1.12e-03, 2.82e-02, 2.15e-02, 1.82e-02
# B_out KL: 9.59e+00, 2.74e+01, 1.58e+01, 3.69e+00
# Psi KL: 2.30e-01, 1.55e+00, 1.17e+00, 8.78e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 248.72063779830933
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 2300 COMPLETE ===========
# Obj: -4.31e+03
# ----------------------------------------
# NELL: -9.52e+03, -1.05e+04, -1.12e+04, -4.17e+03
# W KL: 5.86e+03, 9.32e+03, 9.68e+03, 4.26e+03
# S_in KL: 4.62e+01, 9.17e+00, 4.60e+01, 1.54e+03
# B_in KL: 2.59e+01, 5.49e+01, 1.76e+01, 8.48e+01
# S_out KL: 3.42e-02, 4.20e-01, 4.65e-01, 8.22e-02
# B_out KL: 8.18e+00, 3.60e+01, 4.18e+01, 1.63e+01
# Psi KL: 1.75e-01, 1.57e+00, 1.25e+00, 8.82e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 259.532523393631
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
# =========== EPOCH 2400 COMPLETE ===========
# Obj: -2.19e+02
# ----------------------------------------
# NELL: -7.86e+03, -1.02e+04, -1.12e+04, -2.26e+03
# W KL: 5.82e+03, 9.21e+03, 9.57e+03, 3.87e+03
# S_in KL: 2.46e+02, 8.57e+01, 4.86e+01, 2.16e+03
# B_in KL: 3.92e+01, 3.03e+01, 1.32e+01, 8.85e+01
# S_out KL: 1.56e-02, 8.03e-03, 9.36e-03, 3.38e-03
# B_out KL: 1.35e+00, 3.41e+01, 6.77e+01, 1.13e+01
# Psi KL: 2.17e-01, 1.73e+00, 1.41e+00, 1.01e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 270.3449501991272
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 2500 COMPLETE ===========
# Obj: -4.97e+03
# ----------------------------------------
# NELL: -6.57e+03, -1.04e+04, -1.13e+04, -4.42e+03
# W KL: 4.22e+03, 9.37e+03, 9.74e+03, 4.16e+03
# S_in KL: 3.38e+01, 9.55e+00, 5.22e+00, 1.02e+00
# B_in KL: 3.27e+01, 4.28e+01, 4.78e+01, 1.91e+01
# S_out KL: 7.17e-03, 6.93e-02, 5.64e-02, 2.56e-02
# B_out KL: 1.01e+01, 3.38e+01, 3.20e+01, 9.73e+00
# Psi KL: 4.12e-01, 1.81e+00, 1.47e+00, 4.50e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 281.1689212322235
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 2600 COMPLETE ===========
# Obj: -6.41e+03
# ----------------------------------------
# NELL: -1.00e+04, -1.04e+04, -1.12e+04, -5.23e+03
# W KL: 6.01e+03, 9.38e+03, 9.79e+03, 4.67e+03
# S_in KL: 1.04e+02, 7.62e+01, 5.47e+00, 1.58e+02
# B_in KL: 2.19e+01, 4.59e+01, 4.82e+01, 2.09e+01
# S_out KL: 7.29e-04, 4.15e-02, 7.27e-03, 1.63e-02
# B_out KL: 1.49e+01, 2.97e+01, 3.23e+01, 1.03e+01
# Psi KL: 1.96e-01, 1.56e+00, 1.26e+00, 6.93e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 292.07683181762695
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 2700 COMPLETE ===========
# Obj: -5.79e+03
# ----------------------------------------
# NELL: -9.51e+03, -1.04e+04, -1.13e+04, -5.39e+03
# W KL: 6.46e+03, 9.36e+03, 9.76e+03, 4.83e+03
# S_in KL: 1.30e+01, 9.21e+01, 2.54e+00, 4.79e+01
# B_in KL: 2.76e+01, 3.79e+01, 3.55e+01, 1.92e+01
# S_out KL: 7.95e-03, 4.74e-03, 1.78e-02, 7.91e-02
# B_out KL: 8.60e+00, 2.50e+01, 3.77e+01, 1.12e+01
# Psi KL: 1.74e-01, 1.39e+00, 1.12e+00, 7.55e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 302.8753595352173
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 2800 COMPLETE ===========
# Obj: 1.14e+04
# ----------------------------------------
# NELL: -8.86e+03, -1.03e+04, -1.12e+04, -1.16e+03
# W KL: 5.41e+03, 9.30e+03, 9.72e+03, 4.82e+03
# S_in KL: 3.50e+01, 2.88e+01, 1.15e+02, 1.27e+04
# B_in KL: 1.99e+01, 3.79e+01, 1.38e+01, 2.47e+02
# S_out KL: 3.57e-03, 6.93e-02, 6.79e-02, 1.53e-02
# B_out KL: 4.02e+00, 4.26e+01, 2.02e+02, 8.02e+01
# Psi KL: 1.87e-01, 1.57e+00, 1.35e+00, 7.32e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 313.66249418258667
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 2900 COMPLETE ===========
# Obj: -3.13e+03
# ----------------------------------------
# NELL: -9.67e+03, -1.04e+04, -1.06e+04, -3.13e+03
# W KL: 6.20e+03, 9.34e+03, 9.63e+03, 4.19e+03
# S_in KL: 2.15e+02, 4.70e+00, 8.51e+02, 7.95e+01
# B_in KL: 1.86e+01, 4.78e+01, 5.19e+01, 2.35e+01
# S_out KL: 7.64e-02, 2.03e-01, 2.90e-02, 5.64e-02
# B_out KL: 8.70e+00, 2.94e+01, 2.85e+01, 4.80e+00
# Psi KL: 2.73e-01, 1.66e+00, 1.34e+00, 8.78e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 324.4541382789612
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 3000 COMPLETE ===========
# Obj: -5.63e+03
# ----------------------------------------
# NELL: -9.64e+03, -1.05e+04, -1.11e+04, -5.22e+03
# W KL: 6.14e+03, 9.24e+03, 9.64e+03, 4.85e+03
# S_in KL: 1.02e+02, 1.58e+01, 2.55e+00, 5.89e+02
# B_in KL: 1.02e+01, 3.71e+01, 3.74e+01, 3.09e+01
# S_out KL: 1.30e-01, 2.02e-02, 1.80e-01, 1.17e-02
# B_out KL: 8.66e+00, 3.15e+01, 5.10e+01, 2.14e+01
# Psi KL: 2.69e-01, 1.63e+00, 1.41e+00, 6.07e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 335.2423942089081
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 3100 COMPLETE ===========
# Obj: -3.09e+03
# ----------------------------------------
# NELL: -7.88e+03, -1.02e+04, -1.09e+04, -1.87e+03
# W KL: 5.16e+03, 9.14e+03, 9.50e+03, 3.39e+03
# S_in KL: 8.13e+01, 1.65e+02, 1.54e+02, 5.53e+01
# B_in KL: 2.54e+01, 3.06e+01, 4.39e+01, 1.84e+01
# S_out KL: 1.17e-02, 2.63e-02, 1.85e-02, 1.72e-02
# B_out KL: 4.17e+00, 2.86e+01, 2.33e+01, 8.35e+00
# Psi KL: 5.72e-01, 2.08e+00, 1.86e+00, 8.49e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 346.0481150150299
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 3200 COMPLETE ===========
# Obj: -2.25e+03
# ----------------------------------------
# NELL: -7.98e+03, -1.02e+04, -1.10e+04, -4.92e+03
# W KL: 6.09e+03, 9.25e+03, 9.62e+03, 4.62e+03
# S_in KL: 7.70e+02, 9.26e+02, 3.25e+01, 1.97e+02
# B_in KL: 4.01e+01, 6.43e+01, 4.02e+01, 9.22e+00
# S_out KL: 8.50e+00, 9.47e+00, 2.25e+00, 2.61e+00
# B_out KL: 7.03e+00, 7.55e+01, 3.27e+01, 5.35e+00
# Psi KL: 2.94e-01, 1.71e+00, 1.47e+00, 8.22e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 356.82915449142456
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 3300 COMPLETE ===========
# Obj: -3.15e+03
# ----------------------------------------
# NELL: -8.94e+03, -1.03e+04, -1.10e+04, -6.33e+03
# W KL: 6.63e+03, 9.34e+03, 9.71e+03, 5.03e+03
# S_in KL: 9.89e+02, 2.65e+02, 8.12e+01, 3.66e+01
# B_in KL: 5.99e+01, 2.79e+01, 6.76e+01, 2.60e+01
# S_out KL: 1.19e+02, 5.93e+02, 2.35e+02, 1.75e+02
# B_out KL: 2.87e+00, 1.02e+01, 2.88e+01, 5.29e+00
# Psi KL: 1.91e-01, 1.48e+00, 1.19e+00, 5.27e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 367.6260402202606
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 3400 COMPLETE ===========
# Obj: 7.42e+02
# ----------------------------------------
# NELL: -8.69e+03, -8.50e+03, -8.76e+03, -6.60e+02
# W KL: 5.17e+03, 7.76e+03, 7.78e+03, 3.10e+03
# S_in KL: 1.32e+01, 2.76e+01, 3.92e+01, 4.58e+02
# B_in KL: 5.81e+01, 3.33e+01, 8.92e+00, 1.17e+02
# S_out KL: 2.41e+03, 2.06e+02, 9.31e-01, 1.11e+00
# B_out KL: 1.18e+01, 4.39e+01, 8.88e+01, 1.11e+01
# Psi KL: 6.89e-01, 2.36e+00, 1.97e+00, 2.01e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 378.4176092147827
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 3500 COMPLETE ===========
# Obj: 1.47e+03
# ----------------------------------------
# NELL: -6.87e+03, -1.00e+04, -1.07e+04, -4.64e+03
# W KL: 6.55e+03, 9.15e+03, 9.52e+03, 4.12e+03
# S_in KL: 1.55e+03, 1.14e+03, 8.26e+02, 3.27e+01
# B_in KL: 1.29e+01, 6.12e+01, 5.08e+01, 2.58e+01
# S_out KL: 4.64e+02, 4.39e+00, 4.27e+00, 4.61e+01
# B_out KL: 2.89e+01, 7.37e+01, 4.41e+01, 9.79e+00
# Psi KL: 4.62e-01, 1.84e+00, 1.55e+00, 1.09e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 389.2008934020996
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
# =========== EPOCH 3600 COMPLETE ===========
# Obj: -4.37e+03
# ----------------------------------------
# NELL: -9.99e+03, -1.03e+04, -1.12e+04, -5.58e+03
# W KL: 6.72e+03, 9.26e+03, 9.66e+03, 4.90e+03
# S_in KL: 1.13e+01, 1.35e+02, 3.00e+02, 1.36e+02
# B_in KL: 2.34e+01, 3.95e+01, 5.15e+01, 1.16e+01
# S_out KL: 5.80e+01, 1.35e+03, 4.46e+00, 4.82e+00
# B_out KL: 6.56e+00, 1.98e+01, 2.29e+01, 4.37e+00
# Psi KL: 2.37e-01, 1.52e+00, 1.31e+00, 8.40e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 399.9946961402893
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 3700 COMPLETE ===========
# Obj: 8.82e+03
# ----------------------------------------
# NELL: -4.67e+03, -1.03e+04, -1.11e+04, -2.90e+02
# W KL: 3.90e+03, 9.20e+03, 9.64e+03, 5.12e+03
# S_in KL: 2.11e+01, 7.97e+01, 1.13e+02, 4.91e+03
# B_in KL: 2.98e+01, 2.88e+01, 3.97e+01, 3.80e+01
# S_out KL: 7.28e-02, 1.31e+03, 9.02e+00, 5.83e+02
# B_out KL: 2.39e+01, 4.85e+01, 3.24e+01, 1.15e+01
# Psi KL: 9.20e-01, 1.85e+00, 1.72e+00, 1.93e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 410.79627680778503
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 3800 COMPLETE ===========
# Obj: 4.51e+03
# ----------------------------------------
# NELL: -9.36e+03, -8.56e+03, -1.12e+04, -5.54e+03
# W KL: 6.38e+03, 9.34e+03, 9.75e+03, 4.94e+03
# S_in KL: 6.31e+02, 5.37e+03, 5.23e+02, 6.39e+02
# B_in KL: 4.04e+01, 4.04e+01, 3.74e+01, 8.22e+00
# S_out KL: 6.09e-02, 1.29e+03, 5.58e+01, 4.04e+01
# B_out KL: 4.76e+00, 2.91e+01, 1.30e+01, 2.10e+00
# Psi KL: 2.21e-01, 1.59e+00, 1.38e+00, 9.48e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 421.5918116569519
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 3900 COMPLETE ===========
# Obj: -1.73e+03
# ----------------------------------------
# NELL: -1.05e+04, -9.79e+03, -1.12e+04, -4.92e+03
# W KL: 6.72e+03, 9.31e+03, 9.73e+03, 4.53e+03
# S_in KL: 2.05e+02, 1.39e+03, 5.64e+01, 1.09e+02
# B_in KL: 3.13e+01, 4.29e+01, 4.20e+01, 3.10e+01
# S_out KL: 4.00e+02, 1.89e+03, 7.10e+01, 7.33e+01
# B_out KL: 1.54e+01, 3.84e+01, 3.78e+01, 1.29e+01
# Psi KL: 4.57e-01, 1.59e+00, 1.49e+00, 1.04e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 432.3836176395416
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 4000 COMPLETE ===========
# Obj: -5.25e+03
# ----------------------------------------
# NELL: -9.93e+03, -1.05e+04, -1.10e+04, -4.86e+03
# W KL: 6.00e+03, 9.23e+03, 9.73e+03, 4.47e+03
# S_in KL: 2.23e+01, 1.15e+02, 7.41e+02, 5.02e+02
# B_in KL: 2.67e+01, 3.99e+01, 3.56e+01, 1.44e+01
# S_out KL: 3.17e+00, 1.75e+01, 1.89e+01, 5.67e-01
# B_out KL: 8.94e+00, 2.78e+01, 4.20e+01, 1.24e+01
# Psi KL: 4.70e-01, 1.78e+00, 1.50e+00, 1.07e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 443.1887309551239
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 4100 COMPLETE ===========
# Obj: 8.26e+03
# ----------------------------------------
# NELL: -8.16e+03, -1.04e+04, -1.12e+04, -1.89e+03
# W KL: 6.83e+03, 9.33e+03, 9.73e+03, 5.22e+03
# S_in KL: 1.06e+03, 1.22e+02, 7.72e+01, 6.63e+03
# B_in KL: 1.98e+01, 5.36e+01, 1.62e+01, 8.40e+01
# S_out KL: 3.99e+02, 2.66e+01, 8.93e+01, 1.35e+01
# B_out KL: 1.77e+00, 4.20e+01, 9.84e+01, 2.45e+01
# Psi KL: 3.69e-01, 1.47e+00, 1.21e+00, 1.34e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 454.2557225227356
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 4200 COMPLETE ===========
# Obj: -4.66e+03
# ----------------------------------------
# NELL: -8.80e+03, -1.04e+04, -1.10e+04, -6.48e+03
# W KL: 6.54e+03, 9.32e+03, 9.71e+03, 5.11e+03
# S_in KL: 3.12e+02, 4.50e+01, 3.89e+02, 2.63e+00
# B_in KL: 7.06e+01, 2.09e+01, 4.57e+01, 2.75e+01
# S_out KL: 3.47e+00, 3.64e+02, 1.92e+00, 6.17e+00
# B_out KL: 2.88e+00, 1.67e+01, 2.78e+01, 1.47e+01
# Psi KL: 7.52e-01, 1.59e+00, 1.66e+00, 2.57e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 465.5553603172302
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 4300 COMPLETE ===========
# Obj: 1.84e+03
# ----------------------------------------
# NELL: -4.41e+03, -1.02e+04, -1.12e+04, -4.55e+03
# W KL: 4.67e+03, 9.02e+03, 9.58e+03, 5.01e+03
# S_in KL: 6.44e+01, 7.27e+01, 1.67e+01, 3.49e+03
# B_in KL: 2.01e+01, 1.93e+01, 2.18e+01, 5.19e+01
# S_out KL: 7.10e-01, 1.17e+00, 1.82e+00, 1.17e+00
# B_out KL: 8.88e+00, 5.85e+01, 3.23e+01, 4.23e+00
# Psi KL: 1.32e+00, 2.26e+00, 2.10e+00, 5.30e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 476.79286885261536
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 4400 COMPLETE ===========
# Obj: -4.02e+03
# ----------------------------------------
# NELL: -9.94e+03, -1.05e+04, -1.08e+04, -6.47e+03
# W KL: 6.35e+03, 9.32e+03, 9.78e+03, 5.10e+03
# S_in KL: 1.30e+02, 9.39e+00, 1.45e+03, 2.51e+01
# B_in KL: 2.62e+01, 3.50e+01, 3.41e+01, 2.22e+01
# S_out KL: 9.22e+02, 2.17e+02, 1.42e+02, 8.26e-01
# B_out KL: 6.69e+00, 3.48e+01, 3.81e+01, 1.18e+01
# Psi KL: 2.39e-01, 1.49e+00, 1.24e+00, 7.58e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 488.1476101875305
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 4500 COMPLETE ===========
# Obj: -7.69e+02
# ----------------------------------------
# NELL: -8.71e+03, -1.03e+04, -1.12e+04, -5.90e+03
# W KL: 6.59e+03, 9.30e+03, 9.79e+03, 5.51e+03
# S_in KL: 6.48e+02, 1.53e+02, 3.36e+02, 1.05e+03
# B_in KL: 3.95e+01, 4.35e+01, 4.74e+01, 1.43e+01
# S_out KL: 4.22e+02, 1.22e+03, 6.64e+00, 1.06e+01
# B_out KL: 1.24e+01, 5.42e+01, 4.18e+01, 9.19e+00
# Psi KL: 2.28e-01, 1.55e+00, 1.16e+00, 5.90e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 499.0302872657776
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 4600 COMPLETE ===========
# Obj: -5.82e+03
# ----------------------------------------
# NELL: -1.02e+04, -1.05e+04, -1.13e+04, -6.09e+03
# W KL: 6.66e+03, 9.33e+03, 9.77e+03, 5.47e+03
# S_in KL: 1.82e+02, 8.88e+01, 1.46e+02, 4.42e+02
# B_in KL: 1.69e+01, 3.88e+01, 4.75e+01, 1.10e+01
# S_out KL: 2.51e-02, 4.03e+00, 4.25e-01, 1.38e+01
# B_out KL: 5.45e+00, 4.15e+01, 2.68e+01, 8.48e+00
# Psi KL: 1.46e-01, 1.25e+00, 1.32e+00, 7.71e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 510.06873321533203
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 4700 COMPLETE ===========
# Obj: -6.36e+03
# ----------------------------------------
# NELL: -9.09e+03, -1.05e+04, -1.10e+04, -6.73e+03
# W KL: 5.49e+03, 9.28e+03, 9.65e+03, 5.27e+03
# S_in KL: 1.42e+02, 1.53e+02, 6.53e+02, 2.17e+01
# B_in KL: 2.34e+01, 4.18e+01, 3.61e+01, 2.06e+01
# S_out KL: 2.37e+00, 5.82e+00, 1.12e+02, 8.72e+00
# B_out KL: 8.80e+00, 4.03e+01, 2.26e+01, 9.17e+00
# Psi KL: 4.49e-01, 1.64e+00, 1.49e+00, 5.12e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 521.4559824466705
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
# =========== EPOCH 4800 COMPLETE ===========
# Obj: -3.12e+03
# ----------------------------------------
# NELL: -7.01e+03, -1.02e+04, -1.12e+04, -4.76e+03
# W KL: 4.91e+03, 9.20e+03, 9.63e+03, 4.15e+03
# S_in KL: 3.31e+01, 9.04e+01, 1.04e+02, 9.00e+01
# B_in KL: 3.88e+01, 1.78e+01, 3.78e+01, 3.84e+01
# S_out KL: 2.19e+00, 8.05e+01, 5.11e+00, 1.49e+03
# B_out KL: 6.49e+00, 3.81e+01, 4.22e+01, 7.71e+00
# Psi KL: 1.02e+00, 2.16e+00, 2.04e+00, 7.85e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 532.7986319065094
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00
#
# =========== EPOCH 4900 COMPLETE ===========
# Obj: 2.03e+04
# ----------------------------------------
# NELL: -7.38e+03, -1.04e+04, -1.11e+04, 5.70e+03
# W KL: 7.24e+03, 9.36e+03, 9.80e+03, 5.43e+03
# S_in KL: 1.89e+03, 1.63e+02, 4.32e+02, 8.54e+03
# B_in KL: 1.95e+01, 6.10e+01, 3.56e+01, 4.40e+00
# S_out KL: 1.76e+01, 6.97e+00, 3.35e+02, 1.16e+01
# B_out KL: 9.07e+00, 5.20e+01, 5.53e+01, 1.82e+01
# Psi KL: 2.51e-01, 1.29e+00, 1.22e+00, 8.73e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 544.2425007820129
# ----------------------------------------
# CPU cur memory used (GB): 4.59e+00
# GPU_0 cur memory used (GB): 1.02e+00, max memory used (GB): 1.02e+00

# %% [markdown]
# ## Fit a model to one example individual

# %%
single_fit_ind = 0

# %%
single_fit_rs = fit_with_hypercube_priors(data=[ind_data[single_fit_ind]], 
                                          props=[ind_props[single_fit_ind]], p=p, 
                                          w_prior_opts=fit_w_prior_opts, 
                                          s_in_prior_opts=fit_s_in_prior_opts,
                                          b_in_prior_opts=fit_b_prior_opts,
                                          s_out_prior_opts=fit_s_out_prior_opts,
                                          b_out_prior_opts=fit_b_prior_opts,
                                          psi_prior_opts=fit_psi_prior_opts,
                                          s_in_post_opts=s_in_post_opts,
                                          b_in_post_opts=b_post_opts,
                                          s_out_post_opts=s_out_post_opts,
                                          b_out_post_opts=b_post_opts,
                                          psi_post_opts=psi_post_opts,
                                          dense_net_opts=dense_net_opts, 
                                          sp_fit_opts=single_sp_fit_opts, 
                                          ip_fit_opts=single_ip_fit_opts)
# Out:
# Found 1 GPUs
# Beginning SP fitting.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 5.07e+07
# ----------------------------------------
# NELL: 4.25e+04
# W KL: 0.00e+00
# S_in KL: 2.53e+07
# B_in KL: 2.46e+03
# S_out KL: 2.53e+07
# B_out KL: 2.15e+03
# Psi KL: 7.78e+03
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.030441999435424805
# ----------------------------------------
# CPU cur memory used (GB): 5.60e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
# Beginning IP fitting.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 5.07e+07
# ----------------------------------------
# NELL: 1.15e+04
# W KL: 1.77e+03
# S_in KL: 2.53e+07
# B_in KL: 2.48e+03
# S_out KL: 2.53e+07
# B_out KL: 2.51e+03
# Psi KL: 5.26e-01
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.03281354904174805
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 100 COMPLETE ===========
# Obj: 1.31e+03
# ----------------------------------------
# NELL: 9.27e+02
# W KL: 3.83e+02
# S_in KL: 2.17e-02
# B_in KL: 1.18e-01
# S_out KL: 1.07e-02
# B_out KL: 1.02e-01
# Psi KL: 6.19e-01
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 3.205692768096924
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 200 COMPLETE ===========
# Obj: 1.10e+03
# ----------------------------------------
# NELL: 4.24e+02
# W KL: 6.79e+02
# S_in KL: 3.18e-03
# B_in KL: 3.07e-03
# S_out KL: 4.81e-04
# B_out KL: 6.08e-01
# Psi KL: 2.53e-01
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 6.374856948852539
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 300 COMPLETE ===========
# Obj: 1.07e+03
# ----------------------------------------
# NELL: 5.18e+01
# W KL: 1.02e+03
# S_in KL: 1.64e-02
# B_in KL: 2.13e-03
# S_out KL: 8.10e-05
# B_out KL: 4.33e-01
# Psi KL: 3.87e-02
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 9.564627885818481
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 400 COMPLETE ===========
# Obj: 9.21e+02
# ----------------------------------------
# NELL: -2.63e+02
# W KL: 1.17e+03
# S_in KL: 2.60e+00
# B_in KL: 5.94e-01
# S_out KL: 4.68e-03
# B_out KL: 5.99e+00
# Psi KL: 9.82e-02
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 12.761406183242798
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 500 COMPLETE ===========
# Obj: 7.80e+02
# ----------------------------------------
# NELL: -6.10e+02
# W KL: 1.38e+03
# S_in KL: 2.93e+00
# B_in KL: 6.09e-01
# S_out KL: 1.05e-03
# B_out KL: 2.71e+00
# Psi KL: 1.06e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 15.953850507736206
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 600 COMPLETE ===========
# Obj: 1.66e+02
# ----------------------------------------
# NELL: -9.70e+02
# W KL: 1.14e+03
# S_in KL: 2.60e-02
# B_in KL: 1.73e-03
# S_out KL: 7.20e-05
# B_out KL: 2.88e-02
# Psi KL: 9.71e-03
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 19.133012056350708
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 700 COMPLETE ===========
# Obj: -3.01e+02
# ----------------------------------------
# NELL: -1.55e+03
# W KL: 1.25e+03
# S_in KL: 1.74e-01
# B_in KL: 1.50e-01
# S_out KL: 7.16e-04
# B_out KL: 3.07e-01
# Psi KL: 2.67e-02
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 22.31466293334961
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 800 COMPLETE ===========
# Obj: -1.30e+03
# ----------------------------------------
# NELL: -3.25e+03
# W KL: 1.95e+03
# S_in KL: 5.38e-01
# B_in KL: 1.41e-01
# S_out KL: 1.62e-04
# B_out KL: 4.63e-02
# Psi KL: 3.37e-02
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 25.51308035850525
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 900 COMPLETE ===========
# Obj: -4.62e+03
# ----------------------------------------
# NELL: -1.09e+04
# W KL: 6.32e+03
# S_in KL: 1.01e+00
# B_in KL: 7.30e-02
# S_out KL: 1.27e-03
# B_out KL: 2.99e-01
# Psi KL: 6.83e-02
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 28.70580220222473
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 1000 COMPLETE ===========
# Obj: -5.27e+03
# ----------------------------------------
# NELL: -1.30e+04
# W KL: 7.76e+03
# S_in KL: 2.12e+01
# B_in KL: 4.71e-01
# S_out KL: 2.88e-03
# B_out KL: 7.02e-01
# Psi KL: 5.06e-02
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 31.89895987510681
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 1100 COMPLETE ===========
# Obj: -5.37e+03
# ----------------------------------------
# NELL: -1.36e+04
# W KL: 8.20e+03
# S_in KL: 4.69e+01
# B_in KL: 7.83e-01
# S_out KL: 7.20e-05
# B_out KL: 3.66e-01
# Psi KL: 8.45e-02
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 35.08979678153992
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 1200 COMPLETE ===========
# Obj: -5.76e+03
# ----------------------------------------
# NELL: -1.40e+04
# W KL: 8.21e+03
# S_in KL: 2.87e+00
# B_in KL: 2.01e-01
# S_out KL: 1.93e-03
# B_out KL: 7.08e-01
# Psi KL: 7.50e-02
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 38.264684200286865
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 1300 COMPLETE ===========
# Obj: -5.06e+03
# ----------------------------------------
# NELL: -1.34e+04
# W KL: 8.18e+03
# S_in KL: 1.30e+02
# B_in KL: 8.45e-01
# S_out KL: 3.33e-04
# B_out KL: 6.37e-01
# Psi KL: 2.19e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 41.43826174736023
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 1400 COMPLETE ===========
# Obj: -5.13e+03
# ----------------------------------------
# NELL: -1.32e+04
# W KL: 7.99e+03
# S_in KL: 1.17e+02
# B_in KL: 6.01e-01
# S_out KL: 7.07e-03
# B_out KL: 2.16e-01
# Psi KL: 3.71e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 44.61242341995239
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 1500 COMPLETE ===========
# Obj: -5.59e+03
# ----------------------------------------
# NELL: -1.37e+04
# W KL: 8.11e+03
# S_in KL: 2.15e+01
# B_in KL: 6.00e-01
# S_out KL: 6.12e-04
# B_out KL: 4.95e-01
# Psi KL: 8.74e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 47.77814054489136
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 1600 COMPLETE ===========
# Obj: -5.51e+03
# ----------------------------------------
# NELL: -1.30e+04
# W KL: 7.45e+03
# S_in KL: 5.48e+01
# B_in KL: 1.62e-01
# S_out KL: 1.09e-02
# B_out KL: 7.55e-01
# Psi KL: 4.05e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 50.95676875114441
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
# =========== EPOCH 1700 COMPLETE ===========
# Obj: -5.63e+03
# ----------------------------------------
# NELL: -1.32e+04
# W KL: 7.59e+03
# S_in KL: 2.90e+01
# B_in KL: 2.94e-01
# S_out KL: 4.17e-02
# B_out KL: 3.36e-01
# Psi KL: 2.84e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 54.131446838378906
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 1800 COMPLETE ===========
# Obj: -5.49e+03
# ----------------------------------------
# NELL: -1.24e+04
# W KL: 6.90e+03
# S_in KL: 2.98e+01
# B_in KL: 1.22e+00
# S_out KL: 8.00e-03
# B_out KL: 4.81e-01
# Psi KL: 1.78e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 57.30889654159546
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 1900 COMPLETE ===========
# Obj: -3.97e+03
# ----------------------------------------
# NELL: -9.32e+03
# W KL: 5.32e+03
# S_in KL: 3.38e+01
# B_in KL: 8.64e-01
# S_out KL: 3.57e-03
# B_out KL: 2.84e-01
# Psi KL: 1.37e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 60.48153352737427
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 2000 COMPLETE ===========
# Obj: -4.10e+03
# ----------------------------------------
# NELL: -1.15e+04
# W KL: 7.06e+03
# S_in KL: 3.28e+02
# B_in KL: 8.72e-01
# S_out KL: 8.10e-03
# B_out KL: 7.00e-01
# Psi KL: 1.34e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 63.64336585998535
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 2100 COMPLETE ===========
# Obj: 4.78e+03
# ----------------------------------------
# NELL: -1.51e+03
# W KL: 5.61e+03
# S_in KL: 6.58e+02
# B_in KL: 5.32e+00
# S_out KL: 1.37e-02
# B_out KL: 5.71e+00
# Psi KL: 9.68e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 66.78230738639832
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 2200 COMPLETE ===========
# Obj: -5.21e+03
# ----------------------------------------
# NELL: -1.14e+04
# W KL: 6.23e+03
# S_in KL: 1.04e+01
# B_in KL: 3.92e-01
# S_out KL: 5.22e-03
# B_out KL: 2.58e-01
# Psi KL: 1.82e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 69.94262170791626
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 2300 COMPLETE ===========
# Obj: -4.90e+03
# ----------------------------------------
# NELL: -1.20e+04
# W KL: 7.04e+03
# S_in KL: 6.93e+01
# B_in KL: 1.54e-01
# S_out KL: 4.50e-02
# B_out KL: 6.14e+00
# Psi KL: 1.70e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 73.09907937049866
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01
#
# =========== EPOCH 2400 COMPLETE ===========
# Obj: -5.35e+03
# ----------------------------------------
# NELL: -1.23e+04
# W KL: 6.87e+03
# S_in KL: 4.56e+01
# B_in KL: 1.48e-01
# S_out KL: 3.92e-03
# B_out KL: 4.77e-01
# Psi KL: 1.95e-01
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 76.26266384124756
# ----------------------------------------
# CPU cur memory used (GB): 5.87e+00
# GPU_0 cur memory used (GB): 2.64e-01, max memory used (GB): 2.64e-01

# %% [markdown]
# ## Plot some example data

# %%
# Helper formatting function
def format_box(ax):
    ax.set_aspect('equal', 'box')
    ax.set_xlim(0, 1)
    ax.set_ylim(0, 1)
    plt.xlabel('property dim 1 (a.u.)')
    plt.ylabel('property dim 2 (a.u.)')

# %%
n_plot_vars = 1000 # Number of variables we plot the location of
ex_ind = 0

# %% [markdown]
# ### Show the location of some example variables in property space

# %%
plt.figure(figsize=(7, 7))
ax = plt.subplot(1,1,1)
ax.plot(ind_props[ex_ind][0:n_plot_vars,0], ind_props[ex_ind][0:n_plot_vars,1], 'r.')
format_box(ax)

# %% [markdown]
# ### Plot the mean and standard deviation of the true weight distribution

# %%
overlay_pts = True # True if we want to overlay neuron locations on plots

# %%
pts, dim_pts = list_grid_pts(grid_limits=np.asarray([[0, 1.0], [0, 1.0]]), n_pts_per_dim=[100,100])
pts = torch.tensor(pts, dtype=torch.float)

true_w_mn = true_priors.w_prior(pts).detach().cpu().numpy()
true_w_std = np.concatenate([d.std_f(pts).detach().cpu().numpy() for d in true_priors.w_prior.dists], axis=1)
true_w_mn = true_w_mn.reshape([100,100]).transpose()
true_w_std = true_w_std.reshape([100,100]).transpose()

plt.figure(figsize=(7, 7))
ax = plt.subplot(1,1,1)
im = ax.imshow(true_w_mn, origin='lower', extent=[0, 1.0, 0, 1.0])
mn_vmin, mn_vmax = im.get_clim() # Keep track of color limits
plt.colorbar(im)
format_box(ax)
plt.title('Mean')
if overlay_pts:
    ax.plot(ind_props[ex_ind][0:n_plot_vars,0], ind_props[ex_ind][0:n_plot_vars,1], 'r.')

plt.figure(figsize=(7, 7))
ax = plt.subplot(1,1,1)
im = ax.imshow(true_w_std, origin='lower', extent=[0, 1.0, 0, 1.0])
std_vmin, std_vmax = im.get_clim() # Keep track of color limits
plt.colorbar(im)
format_box(ax)
plt.title('Standard Deviation')
if overlay_pts:
    ax.plot(ind_props[ex_ind][0:n_plot_vars,0], ind_props[ex_ind][0:n_plot_vars,1], 'r.')

# %% [markdown]
# ### Plot the sampled weights for the example individual

# %%
plot_w_vls = ind_true_mdls[ex_ind].w.detach().numpy()[0:n_plot_vars]
plow_w_vls_scaled = (plot_w_vls - mn_vmin)/(mn_vmax - mn_vmin)
plot_w_clrs = cm.viridis(plow_w_vls_scaled)

plt.figure(figsize=(7, 7))
ax = plt.subplot(1,1,1)
ax.scatter(ind_props[ex_ind][0:n_plot_vars,0], ind_props[ex_ind][0:n_plot_vars,1], marker='.', color=plot_w_clrs)
format_box(ax)
plt.title('Sampled Weights')

# %% [markdown]
# ## Plot the true low-d function and the true data from the example individual

# %%
n_plot_smps = 100

# %%
f_x_vls = torch.linspace(-2, 2, 100)
true_f_vls = ind_true_mdls[0].m(f_x_vls).detach().numpy()
f_x_vls = f_x_vls.detach().numpy()

ex_proj_x_vls = ind_true_mdls[ex_ind].project(x=ind_data[ex_ind][0]).detach().numpy()[0:n_plot_smps]
ex_y_vls = ind_data[ex_ind][1].detach().numpy()[0:n_plot_smps]

# %%
plt.figure(figsize=(9, 6.5))
plt.plot(ex_proj_x_vls, ex_y_vls, 'ro')
plt.plot(f_x_vls, true_f_vls, color='w')
plt.xlabel('Projected x (a.u.)')
plt.ylabel('y (a.u.)')

# %% [markdown]
# ### Plot the true low-d function and the predictions from the example individual

# %%
fit_type = 'comb'  # 'comb' or 'single'
exam_type = 'ip'

# %%
if fit_type == 'single':
    fit_rs = single_fit_rs
else:
    fit_rs = comb_fit_rs

if exam_type == 'sp':
    exam_priors = fit_rs['sp']['priors']
    exam_posts = [coll.posteriors for coll in fit_rs['sp']['vi_collections']]
    exam_vi_collections = fit_rs['sp']['vi_collections']
    exam_mdls = [coll.mdl for coll in fit_rs['sp']['vi_collections']]
    exam_logs = fit_rs['sp']['logs']
else:
    exam_priors = fit_rs['ip']['priors']
    exam_posts = [coll.posteriors for coll in fit_rs['ip']['vi_collections']]
    exam_vi_collections = fit_rs['ip']['vi_collections']
    exam_mdls = [coll.mdl for coll in fit_rs['ip']['vi_collections']]
    exam_logs = fit_rs['ip']['logs']

# %%
exam_w = exam_posts[ex_ind].w_post(ind_props[ex_ind])
exam_s_in = exam_posts[ex_ind].s_in_post(ind_props[ex_ind]).squeeze(axis=1)
exam_b_in = exam_posts[ex_ind].b_in_post(ind_props[ex_ind]).squeeze(axis=1)
exam_s_out = exam_posts[ex_ind].s_out_post(ind_props[ex_ind]).squeeze(axis=1)
exam_b_out = exam_posts[ex_ind].b_out_post(ind_props[ex_ind]).squeeze(axis=1)
exam_psi = exam_posts[ex_ind].psi_post.dists[0].mode(ind_props[ex_ind]).squeeze(axis=1)

# %%
n_exam_smps = 1000

# %%
x_exam = torch.tensor(sample_proj_data_from_interval(n_smps=n_exam_smps, 
                                                      w=ind_true_mdls[ex_ind].w.detach().numpy(), 
                                                      interval=[intervals[0], intervals[-1]]),
                       dtype=torch.float)

# %%
with torch.no_grad():
    
    # Determine which of our test points are in and out of the training distribution for this individual 
    x_true_proj = ind_true_mdls[ex_ind].project(x_exam).numpy()
    x_true_proj_for_int = ind_true_mdls[ex_ind].project(x_exam, apply_scales_and_biases=False).numpy().squeeze()
    
    x_within_train_dist = np.logical_and(x_true_proj_for_int >= intervals[ex_ind], 
                                         x_true_proj_for_int < intervals[ex_ind+1])
    x_outside_train_dist = np.logical_not(x_within_train_dist)
    
    # Get true mean and predicted mean for each data point for this individual 
    true_mns = ind_true_mdls[ex_ind].m(ind_true_mdls[ex_ind].project(x_exam)).numpy()
    pred_mns = exam_mdls[ex_ind].cond_mean(x=x_exam, w=exam_w, s_in=exam_s_in, b_in=exam_b_in, 
                                             s_out=exam_s_out, b_out=exam_b_out)
    x_pred_proj = exam_mdls[ex_ind].project(x=x_exam, w=exam_w, s_in=exam_s_in, b_in=exam_b_in)

# %%
align_vls = align_low_d_spaces(w_0=ind_true_mdls[ex_ind].w.detach().numpy(),
                               s_in_0=ind_true_mdls[ex_ind].s_in.detach().numpy(),
                               b_in_0=ind_true_mdls[ex_ind].b_in.detach().numpy(),
                               w_1=exam_w.detach().numpy(),
                               s_in_1=exam_s_in.detach().numpy(),
                               b_in_1=exam_b_in.detach().numpy(),
                               z_1=x_pred_proj.numpy())

x_pred_proj_aligned = align_vls[-1]

# %%
true_clrs = np.zeros([n_exam_smps,4])
true_clrs[:,-1] = 1.0
true_clrs[x_outside_train_dist, 0] = 1.0

pred_clrs = np.zeros([n_exam_smps,4])
pred_clrs[:, -1] = 1.0
pred_clrs[x_outside_train_dist, 0:3] = .5
#pred_clrs[x_outside_train_dist, -1] = 0 
pred_clrs[np.logical_not(x_outside_train_dist), 0] = .7


plt.figure(figsize=(9, 6.5))
a = plt.subplot(1,1,1)
a.scatter(x_true_proj, pred_mns, color=pred_clrs)
plt.ylim([-2.5, 2])

plt.plot(f_x_vls, true_f_vls, color='w')
plt.xlabel('Projected x (a.u.)')
plt.ylabel('y (a.u.)')

# %% [markdown]
# ### Plot the learned priors

# %%
pred_w_mn = exam_priors.w_prior(pts).detach().cpu().numpy()
pred_w_std = np.concatenate([d.std_f(pts).detach().cpu().numpy() for d in exam_priors.w_prior.dists], axis=1)

true_w_mn = true_priors.w_prior(pts).detach().cpu().numpy()

pred_mn_supp = np.concatenate([pred_w_mn, np.ones([pred_w_mn.shape[0], 1])], axis=1)
t = numpy.linalg.lstsq(pred_mn_supp, true_w_mn, rcond=None)
t = t[0]
pred_mn_al = np.matmul(pred_mn_supp, t)
pred_mn_al = pred_mn_al.reshape([100,100]).transpose()


t_std = t[0]
pred_w_std_al = np.zeros(pred_w_std.shape)
for i, std_i in enumerate(pred_w_std):
    pred_w_std_al[i, :] = np.abs(t_std)*std_i
pred_w_std_al = pred_w_std_al.reshape([100,100]).transpose()

# %%
plt.figure(figsize=(7, 7))
ax = plt.subplot(1,1,1)
im = ax.imshow(pred_mn_al, origin='lower', extent=[0, 1.0, 0, 1.0], vmin=mn_vmin, vmax=mn_vmax)
plt.colorbar(im)
format_box(ax)
plt.title('Estimated Mean')

plt.figure(figsize=(7, 7))
ax = plt.subplot(1,1,1)
im = ax.imshow(pred_w_std_al, origin='lower', extent=[0, 1.0, 0, 1.0], vmin=std_vmin, vmax=std_vmax)
plt.colorbar(im)
format_box(ax)
plt.title('Estimated Standard Deviation')

# %% [markdown]
# ## Look at fitting logs

# %%
for log in exam_logs:
    Fitter.plot_log(log)

# %% [markdown]
# ## Look at individual model parameters

# %%
exam_ind = 0

# %%
exam_mdl = GNLRMdl(m = exam_vi_collections[ex_ind].mdl.m, w=exam_w, s_in=exam_s_in, b_in=exam_b_in, 
                  s_out=exam_s_out, b_out=exam_b_out, psi=exam_psi)

plt.figure()
GNLRMdl.compare_mdls(ind_true_mdls[exam_ind], exam_mdl)

# %% [markdown]
# ## Debug

# %%
import numpy.random
import numpy.linalg

# %%
m = numpy.random.randn(10, 10)

# %%
u, _, _ = numpy.linalg.svd(m)

# %%
u[:,0]

# %%
plt.imshow(np.matmul(u, u.transpose()))
