# %% [markdown]
# Here we fit models across fish, looking at the latent representations of different conditions for all fish in the same
# low-d space.  We initialize with shared posteriors, use these for initialization when fitting with the individual posteriors and then use early stopping to prevent overfitting when fitting with the individual posteriors.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import copy
from itertools import chain
from pathlib import Path

from matplotlib import cm
import matplotlib.pyplot as plt
import numpy as np
from numpy.linalg import svd
import torch

import sklearn.decomposition as decomposition

from ahrens_wbo.annotations import label_subperiods
from ahrens_wbo.data_processing import load_and_preprocess_data
from janelia_core.ml.utils import list_torch_devices
from janelia_core.visualization.image_generation import max_project_pts
from janelia_core.visualization.image_generation import generate_dot_image_3d
from janelia_core.visualization.image_generation import scalar_3d_max_project
from janelia_core.visualization.matrix_visualization import cmp_n_mats
from probabilistic_model_synthesis.fa import FAMdl
from probabilistic_model_synthesis.fa import Fitter
from probabilistic_model_synthesis.fa import evaluate_check_points
from probabilistic_model_synthesis.fa import generate_basic_posteriors
from probabilistic_model_synthesis.fa import generate_hypercube_prior_collection
from probabilistic_model_synthesis.fa import generate_simple_prior_collection
from probabilistic_model_synthesis.fa import infer_latents
from probabilistic_model_synthesis.fa import initialize_basic_posteriors
from probabilistic_model_synthesis.fa import orthonormalize
from probabilistic_model_synthesis.fa import PosteriorCollection
from probabilistic_model_synthesis.fa import PriorCollection
from probabilistic_model_synthesis.fa import VICollection

# %%
# %matplotlib notebook

# %% [markdown]
# ## Parameters go here

# %%
ps = dict()

# Specify the directory where all the raw data is found
ps['data_dir'] = r'/groups/bishop/bishoplab/projects/ahrens_wbo/data'

# Here we list the subject we want to fit and the conditions we want to fit on for each subject
ps['fit_specs'] = {8: ['omr_forward'], 
                   9: ['omr_left'], 
                   11: ['omr_right']} 
                   
# Here we specify if we fit in conditions with shock or not
ps['shock'] = False

# Specify the number of latent variables in the FA models
ps['n_latent_vars'] = 10

# Number of inidividual slices of each type of subperiod we use for validation
ps['n_validation_slices'] = 2

# True if we should use early stopping
ps['use_early_stopping'] = True

# Folder where checkpoints will be saved
ps['cp_save_folder'] = r'/groups/bishop/bishoplab/projects/probabilistic_model_synthesis/results/testing'

# %% [markdown]
# ## See which devices are available for fitting

# %%
devices, _ = list_torch_devices()
# Out:
# Found 1 GPUs

# %% [markdown]
# ## Load the data for each subject

# %%
subjects = list(ps['fit_specs'].keys())

# %%
datasets, neuron_locs = load_and_preprocess_data(data_folder=ps['data_dir'], 
                                                 subjects=subjects, 
                                                 neural_gain=10)
# Out:
# Done loading data for subject subject_8.
# Done loading data for subject subject_9.
# Done loading data for subject subject_11.

# %% [markdown]
# ## Form the fitting and validation data for each subject

# %%
all_subperiods = set(chain(*[v for v in ps['fit_specs'].values()]))
label_map = {sp: sp_i for sp_i, sp in enumerate(all_subperiods)}

# %%
fit_data = dict()
validation_data = dict()
fit_labels = dict()
validation_labels = dict()

for s_n, dataset in datasets.items():
    
    data_n = datasets[s_n].ts_data['dff']['vls'][:]
    
    # Label the subperiods for this subject
    subperiods = label_subperiods(dataset.ts_data['stim']['vls'][:])
    
    # Down select to only the subperiods we want to fit on for this subject
    subperiods = {k:v for k, v in subperiods.items() if k in ps['fit_specs'][s_n]}
    
    # Down select to the shock condition we want to fit
    subperiods = {k: [sp_i for sp_i in v if sp_i['shock'] == ps['shock']] for k, v in subperiods.items()} 
    
    # Randomly select subperiods for training and validation
    fit_subperiods = dict()
    validation_subperiods = dict()
    for sp_key, sp_slices in subperiods.items():
        
        n_slices = len(sp_slices)
        validation_inds = np.random.choice(n_slices, ps['n_validation_slices'], replace=False)
        
        validation_slices = [sp_slices[s_i] for s_i in range(n_slices) if s_i in validation_inds]
        fit_slices = [sp_slices[s_i] for s_i in range(n_slices) if s_i not in validation_inds]
        
        validation_subperiods[sp_key] = validation_slices
        fit_subperiods[sp_key] = fit_slices

    # Pull out the fitting data for this subject
    fit_data[s_n] = {k:np.concatenate([data_n[sl['slice'], :] for sl in v], axis=0) 
                     for k, v in fit_subperiods.items()}
    
    validation_data[s_n] = {k:np.concatenate([data_n[sl['slice'], :] for sl in v], axis=0) 
                            for k, v in validation_subperiods.items()}
    
    # Generate numerical labels for each data point
    fit_labels[s_n] = {k:label_map[k]*np.ones(np.sum([sl_i['slice'].stop - sl_i['slice'].start for sl_i in v])) 
                       for k, v in fit_subperiods.items()}
    validation_labels[s_n] = {k:label_map[k]*np.ones(np.sum([sl_i['slice'].stop - sl_i['slice'].start for sl_i in v])) 
                              for k, v in validation_subperiods.items()}

# %%
fit_data_conc = {k: np.concatenate([data for data in v.values()], axis=0) 
                 for k, v in fit_data.items()}
fit_labels_conc = {k: np.concatenate([lbls for lbls in v.values()], axis=0) 
                   for k, v in fit_labels.items()}

validation_data_conc = {k: np.concatenate([data for data in v.values()], axis=0) 
                        for k, v in validation_data.items()}
validation_labels_conc = {k: np.concatenate([lbls for lbls in v.values()], axis=0) 
                          for k, v in validation_labels.items()}

# %% [markdown]
# ## Prepare things we will need for eventual plotting

# %%
n_subperiods = len(label_map)
subperiod_clrs = {k: cm.Set1(k_i/(n_subperiods-1)) for k_i, k in enumerate(label_map.keys())}
subject_markers = {8: 'o', 9: 'v', 10: 's', 11:'X'}

# %% [markdown]
# ## Setup everything for fitting FA models with shared posteriors

# %%
sp_priors = generate_hypercube_prior_collection(n_latent_vars=ps['n_latent_vars'], 
                                                hc_params={'n_divisions_per_dim': [100, 100, 25], 
                                                           'dim_ranges': np.asarray([[0, 990.0], 
                                                                                      [0, 610.0], 
                                                                                      [0, 350.0]]),
                                                           'n_div_per_hc_side_per_dim': [1, 1, 1]}, 
                                                min_gaussian_std=.0000001,
                                                lm_mn_init=0.0,
                                                lm_std_init=1.0, 
                                                mn_mn_init=0.0, 
                                                mn_std_init=1.0, 
                                                psi_conc_vl_init=.2,
                                                psi_rate_vl_init=.1,
                                                min_gamma_conc_vl=.001,
                                                min_gamma_rate_vl=.000001)
                                                 
    
sp_posteriors = generate_basic_posteriors(n_obs_vars=[data_n.shape[1] for data_n in fit_data_conc.values()],
                                           n_smps=[data_n.shape[0] for data_n in fit_data_conc.values()],
                                           n_latent_vars=ps['n_latent_vars'])
sp_posteriors = {s_n: sp_posteriors[s_i] for s_i, s_n in enumerate(subjects)}

sp_fit_mdls = {k:FAMdl(lm=None, mn=None, psi=None) for k, data_n in fit_data_conc.items()}
                    
                    
                   
sp_vi_collections = [VICollection(data=torch.tensor(fit_data_conc[s_n]), 
                                  props=neuron_locs[s_n],
                                  mdl = sp_fit_mdls[s_n],
                                  posteriors = sp_posteriors[s_n])
                     for s_i, s_n in enumerate(fit_data_conc.keys())]

# %% [markdown]
# ## Tie the posteriors to the priors

# %%
for vi_coll in sp_vi_collections:
    vi_coll.posteriors.lm_post = sp_priors.lm_prior
    vi_coll.posteriors.mn_post = sp_priors.mn_prior

# %% [markdown]
# ## Fit the sp models

# %%
sp_fitter = Fitter(vi_collections=sp_vi_collections, priors=sp_priors)

# %%
sp_fitter.distribute(distribute_data=True, devices=devices)
sp_log = sp_fitter.fit(1000, milestones=[300, 500, 700, 1200], update_int=100, init_lr=.1, 
                       skip_lm_kl=False, skip_mn_kl=False, skip_psi_kl=False)
sp_fitter.distribute(devices=[torch.device('cpu')])
# Out:
# =========== EPOCH 0 COMPLETE ===========
# Obj: 4.01e+08
# ----------------------------------------
# NELL: 2.48e+08, 6.62e+07, 8.62e+07
# Latent KL: 2.81e+02, 7.73e+01, 6.84e+01
# LM KL: 0.00e+00, 0.00e+00, 0.00e+00
# Mn KL: 0.00e+00, 0.00e+00, 0.00e+00
# Psi KL: 9.62e+04, 1.11e+05, 1.41e+05
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 1.2737233638763428
# ----------------------------------------
# CPU cur memory used (GB): 2.67e+01
# GPU_0 cur memory used (GB): 3.05e-01, max memory used (GB): 3.05e-01
#
# =========== EPOCH 100 COMPLETE ===========
# Obj: 6.38e+07
# ----------------------------------------
# NELL: 4.10e+07, 1.04e+07, 1.23e+07
# Latent KL: 1.95e+04, 3.92e+03, 3.75e+03
# LM KL: 0.00e+00, 0.00e+00, 0.00e+00
# Mn KL: 0.00e+00, 0.00e+00, 0.00e+00
# Psi KL: 3.72e+04, 3.72e+04, 4.31e+04
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 38.418513774871826
# ----------------------------------------
# CPU cur memory used (GB): 2.67e+01
# GPU_0 cur memory used (GB): 3.05e-01, max memory used (GB): 3.05e-01
#
# =========== EPOCH 200 COMPLETE ===========
# Obj: 6.24e+07
# ----------------------------------------
# NELL: 4.06e+07, 1.01e+07, 1.16e+07
# Latent KL: 1.60e+04, 3.60e+03, 4.11e+03
# LM KL: 0.00e+00, 0.00e+00, 0.00e+00
# Mn KL: 0.00e+00, 0.00e+00, 0.00e+00
# Psi KL: 3.96e+04, 4.02e+04, 4.51e+04
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 74.53229236602783
# ----------------------------------------
# CPU cur memory used (GB): 2.67e+01
# GPU_0 cur memory used (GB): 3.05e-01, max memory used (GB): 3.05e-01
#
# =========== EPOCH 300 COMPLETE ===========
# Obj: 6.08e+07
# ----------------------------------------
# NELL: 3.97e+07, 9.83e+06, 1.11e+07
# Latent KL: 1.92e+04, 3.54e+03, 4.10e+03
# LM KL: 0.00e+00, 0.00e+00, 0.00e+00
# Mn KL: 0.00e+00, 0.00e+00, 0.00e+00
# Psi KL: 4.59e+04, 4.45e+04, 4.99e+04
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 110.13494038581848
# ----------------------------------------
# CPU cur memory used (GB): 2.67e+01
# GPU_0 cur memory used (GB): 3.05e-01, max memory used (GB): 3.05e-01
#
# =========== EPOCH 400 COMPLETE ===========
# Obj: 5.98e+07
# ----------------------------------------
# NELL: 3.93e+07, 9.54e+06, 1.08e+07
# Latent KL: 1.97e+04, 5.72e+03, 5.95e+03
# LM KL: 0.00e+00, 0.00e+00, 0.00e+00
# Mn KL: 0.00e+00, 0.00e+00, 0.00e+00
# Psi KL: 4.40e+04, 4.22e+04, 4.76e+04
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 146.27742958068848
# ----------------------------------------
# CPU cur memory used (GB): 2.67e+01
# GPU_0 cur memory used (GB): 3.05e-01, max memory used (GB): 3.05e-01
#
# =========== EPOCH 500 COMPLETE ===========
# Obj: 5.96e+07
# ----------------------------------------
# NELL: 3.91e+07, 9.51e+06, 1.08e+07
# Latent KL: 2.02e+04, 5.88e+03, 6.08e+03
# LM KL: 0.00e+00, 0.00e+00, 0.00e+00
# Mn KL: 0.00e+00, 0.00e+00, 0.00e+00
# Psi KL: 4.29e+04, 4.14e+04, 4.64e+04
# ----------------------------------------
# LR: 0.0010000000000000002
# Elapsed time (secs): 181.27211737632751
# ----------------------------------------
# CPU cur memory used (GB): 2.67e+01
# GPU_0 cur memory used (GB): 3.05e-01, max memory used (GB): 3.05e-01
#
# =========== EPOCH 600 COMPLETE ===========
# Obj: 5.96e+07
# ----------------------------------------
# NELL: 3.91e+07, 9.50e+06, 1.08e+07
# Latent KL: 2.03e+04, 5.90e+03, 6.11e+03
# LM KL: 0.00e+00, 0.00e+00, 0.00e+00
# Mn KL: 0.00e+00, 0.00e+00, 0.00e+00
# Psi KL: 4.29e+04, 4.14e+04, 4.64e+04
# ----------------------------------------
# LR: 0.0010000000000000002
# Elapsed time (secs): 216.2966115474701
# ----------------------------------------
# CPU cur memory used (GB): 2.67e+01
# GPU_0 cur memory used (GB): 3.05e-01, max memory used (GB): 3.05e-01
#
# =========== EPOCH 700 COMPLETE ===========
# Obj: 5.95e+07
# ----------------------------------------
# NELL: 3.91e+07, 9.49e+06, 1.08e+07
# Latent KL: 2.04e+04, 5.90e+03, 6.14e+03
# LM KL: 0.00e+00, 0.00e+00, 0.00e+00
# Mn KL: 0.00e+00, 0.00e+00, 0.00e+00
# Psi KL: 4.28e+04, 4.14e+04, 4.63e+04
# ----------------------------------------
# LR: 0.00010000000000000003
# Elapsed time (secs): 251.54582023620605
# ----------------------------------------
# CPU cur memory used (GB): 2.67e+01
# GPU_0 cur memory used (GB): 3.05e-01, max memory used (GB): 3.05e-01
#
# =========== EPOCH 800 COMPLETE ===========
# Obj: 5.95e+07
# ----------------------------------------
# NELL: 3.91e+07, 9.49e+06, 1.08e+07
# Latent KL: 2.04e+04, 5.92e+03, 6.14e+03
# LM KL: 0.00e+00, 0.00e+00, 0.00e+00
# Mn KL: 0.00e+00, 0.00e+00, 0.00e+00
# Psi KL: 4.28e+04, 4.14e+04, 4.63e+04
# ----------------------------------------
# LR: 0.00010000000000000003
# Elapsed time (secs): 286.83678698539734
# ----------------------------------------
# CPU cur memory used (GB): 2.67e+01
# GPU_0 cur memory used (GB): 3.05e-01, max memory used (GB): 3.05e-01
#
# =========== EPOCH 900 COMPLETE ===========
# Obj: 5.95e+07
# ----------------------------------------
# NELL: 3.91e+07, 9.50e+06, 1.08e+07
# Latent KL: 2.04e+04, 5.92e+03, 6.14e+03
# LM KL: 0.00e+00, 0.00e+00, 0.00e+00
# Mn KL: 0.00e+00, 0.00e+00, 0.00e+00
# Psi KL: 4.28e+04, 4.13e+04, 4.63e+04
# ----------------------------------------
# LR: 0.00010000000000000003
# Elapsed time (secs): 322.22037172317505
# ----------------------------------------
# CPU cur memory used (GB): 2.67e+01
# GPU_0 cur memory used (GB): 3.05e-01, max memory used (GB): 3.05e-01

# %% [markdown]
# ## Infer latents on validation data with the sp models

# %%
sp_validation_latent_posts ={s_n: infer_latents(vi_collection=sp_vi_collections[s_i],
                                                data=torch.tensor(validation_data_conc[s_n]),
                                                fit_opts={'n_epochs': 1000, 'init_lr':.1, 'update_int':500, 
                                                          'milestones': [500]}, 
                                                device=devices[0])[0]
                         for s_i, s_n in enumerate(subjects)}
# Out:
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.13e+07
# ----------------------------------------
# NELL: 1.13e+07
# Latent KL: 2.94e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.05181384086608887
# ----------------------------------------
# CPU cur memory used (GB): 2.70e+01
# GPU_0 cur memory used (GB): 5.84e-02, max memory used (GB): 5.84e-02
#
# =========== EPOCH 500 COMPLETE ===========
# Obj: 5.50e+06
# ----------------------------------------
# NELL: 5.50e+06
# Latent KL: 1.42e+03
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 18.706604957580566
# ----------------------------------------
# CPU cur memory used (GB): 2.70e+01
# GPU_0 cur memory used (GB): 5.84e-02, max memory used (GB): 5.84e-02
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.53e+07
# ----------------------------------------
# NELL: 1.53e+07
# Latent KL: 2.08e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.05081653594970703
# ----------------------------------------
# CPU cur memory used (GB): 2.70e+01
# GPU_0 cur memory used (GB): 5.50e-02, max memory used (GB): 5.50e-02
#
# =========== EPOCH 500 COMPLETE ===========
# Obj: 3.73e+06
# ----------------------------------------
# NELL: 3.73e+06
# Latent KL: 1.22e+03
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 18.9909770488739
# ----------------------------------------
# CPU cur memory used (GB): 2.70e+01
# GPU_0 cur memory used (GB): 5.50e-02, max memory used (GB): 5.50e-02
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.02e+07
# ----------------------------------------
# NELL: 2.02e+07
# Latent KL: 2.12e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.05572199821472168
# ----------------------------------------
# CPU cur memory used (GB): 2.70e+01
# GPU_0 cur memory used (GB): 5.89e-02, max memory used (GB): 5.89e-02
#
# =========== EPOCH 500 COMPLETE ===========
# Obj: 4.56e+06
# ----------------------------------------
# NELL: 4.56e+06
# Latent KL: 1.32e+03
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 20.978907346725464
# ----------------------------------------
# CPU cur memory used (GB): 2.70e+01
# GPU_0 cur memory used (GB): 5.89e-02, max memory used (GB): 5.89e-02

# %% [markdown]
# ## Look at the log for fitting the sp model

# %%
sp_fitter.plot_log(sp_log)
# Out:
# [True, True, True, True, True, True]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## View latents estimated with the sp models

# %%
props_conc = torch.cat([locs for locs in neuron_locs.values()], dim=0)
sp_prior_lm_conc = sp_priors.lm_prior(props_conc).detach().numpy()
view_validaton = False # True if we should view validation latents

# %%
sp_latents = dict()
if view_validaton:
    sp_view_latents_post = sp_validation_latent_posts
else:
    sp_view_latents_post = {k: sp_posteriors[k].latent_post for k in sp_posteriors.keys()}
    
for s_n, latent_post_n in sp_view_latents_post.items():

    latents_n = latent_post_n.mns.detach().numpy()
    _, latents_o = orthonormalize(sp_prior_lm_conc, latents_n, unit_len_columns=False )
        
    sp_latents[s_n] = {'latents': latents_n, 'latents_o': latents_o}

# %%
start_dim = 0

plt.figure()
ax = plt.axes(projection='3d')

for s_i, s_n in enumerate(sp_latents.keys()):
    plot_latents = sp_latents[s_n]['latents_o']
    if view_validaton:
        plot_labels = validation_labels_conc[s_n]
    else:
        plot_labels = fit_labels_conc[s_n]
    
    
    for sp, sp_lbl in label_map.items():
        sp_clr = subperiod_clrs[sp]
        sp_inds = plot_labels == sp_lbl
        ax.scatter(plot_latents[sp_inds,start_dim+0], plot_latents[sp_inds,start_dim+1], 
                   plot_latents[sp_inds,start_dim+2], color=sp_clr, marker=subject_markers[s_n])
    plt.title(str(s_n))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Visualize loading matrices across space for the sp models

# %%
vis_comp = 1

# %%
_, _, o_vis = svd(sp_prior_lm_conc, full_matrices=False)

mode_imgs = dict()
for s_n in subjects:
    neuron_locs_n = neuron_locs[s_n]
    
    lm_n = sp_posteriors[s_n].lm_post(neuron_locs_n).detach().numpy()
    lm_n = np.matmul(lm_n, o_vis.transpose())
    
    mode_imgs[s_n], _ = max_project_pts(dot_positions=neuron_locs_n.numpy()[:,[0,1]].astype('float'),
                                        dot_vls=lm_n[:,vis_comp], 
                                        box_position=np.asarray([[0, 0], [990, 610]]), 
                                        n_divisions=np.asarray([990, 610]), 
                                        dot_dim_width=np.asarray([5,5]))
    
plt.figure()
cmp_n_mats([mode_imgs[k] for k in mode_imgs.keys()])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]

# %% [markdown]
# ## Setup everything for fitting models with individual posteriors

# %%
ip_priors = copy.deepcopy(sp_priors)

ip_posteriors = generate_basic_posteriors(n_obs_vars=[data_n.shape[1] for data_n in fit_data_conc.values()],
                                           n_smps=[data_n.shape[0] for data_n in fit_data_conc.values()],
                                           n_latent_vars=ps['n_latent_vars'], 
                                           mn_opts={'std_lb': .00000001, 'std_ub': 10.0}, 
                                           lm_opts={'std_lb': .00000001, 'std_ub': 10.0},
                                           psi_opts={'alpha_lb': .1, 'beta_lb': .000001})
ip_posteriors = {s_n: ip_posteriors[s_i] for s_i, s_n in enumerate(subjects)}

# %%
for s_n, posteriors in ip_posteriors.items():
    
    # Initialize the poseteriors for the mean vectors
    with torch.no_grad():
        mn_prior_mn = sp_priors.mn_prior(neuron_locs[s_n]).squeeze()
        mn_prior_std = sp_priors.mn_prior.std_f(neuron_locs[s_n]).squeeze()
    
        posteriors.mn_post.dists[0].mn_f.f.vl.data = copy.deepcopy(mn_prior_mn)
        posteriors.mn_post.dists[0].std_f.f.set_value(copy.deepcopy(mn_prior_std.numpy()))
        
    # Initialize the posteriors for the loading matrices
    with torch.no_grad():
        for d_i in range(ps['n_latent_vars']):
            lm_prior_mn = sp_priors.lm_prior.dists[d_i](neuron_locs[s_n]).squeeze()
            lm_prior_std = sp_priors.lm_prior.dists[d_i].std_f(neuron_locs[s_n]).squeeze()
            
            posteriors.lm_post.dists[d_i].mn_f.f.vl.data = copy.deepcopy(lm_prior_mn)
            posteriors.lm_post.dists[d_i].std_f.f.set_value(copy.deepcopy(lm_prior_std.numpy()))
        
    # Initialize the posteriors for the private variances
    posteriors.psi_post = copy.deepcopy(sp_posteriors[s_n].psi_post)
    
    # Initialize the posteriors for the latents
    with torch.no_grad():
        posteriors.latent_post = copy.deepcopy(sp_posteriors[s_n].latent_post)
# Out:
# /groups/bishop/bishoplab/projects/janelia_core/janelia_core/ml/extra_torch_modules.py:189: RuntimeWarning: divide by zero encountered in arctanh
#   init_v = np.arctanh(y)

# %%
ip_fit_mdls = {k:FAMdl(lm=None, mn=None, psi=None) for k, data_n in fit_data_conc.items()}
                    
                    
                   
ip_vi_collections = [VICollection(data=torch.tensor(fit_data_conc[s_n]), 
                                  props=neuron_locs[s_n],
                                  mdl = ip_fit_mdls[s_n],
                                  posteriors = ip_posteriors[s_n])
                     for s_i, s_n in enumerate(fit_data_conc.keys())]

# %% [markdown]
# ## Fit the ip models

# %%
ip_fitter = Fitter(vi_collections=ip_vi_collections, priors=ip_priors)

# %%
ip_fitter.distribute(distribute_data=True, devices=devices)
ip_log = ip_fitter.fit(500, milestones=[300, 500, 700], update_int=100, init_lr=.01, 
                       skip_lm_kl=False, skip_mn_kl=False, skip_psi_kl=False, 
                       cp_save_folder=ps['cp_save_folder'], cp_epochs=np.arange(0, 1000, 10))
# Out:
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.72e+08
# ----------------------------------------
# NELL: 3.91e+07, 9.51e+06, 1.08e+07
# Latent KL: 1.87e+04, 5.00e+03, 5.28e+03
# LM KL: 1.53e+04, 1.28e+04, 1.61e+04
# Mn KL: 1.99e+07, 6.94e+07, 2.27e+07
# Psi KL: 4.32e+04, 4.14e+04, 4.65e+04
# ----------------------------------------
# LR: 0.01
# Elapsed time (secs): 0.3944211006164551
# ----------------------------------------
# CPU cur memory used (GB): 2.72e+01
# GPU_0 cur memory used (GB): 4.08e-01, max memory used (GB): 4.08e-01
# Saved check point for epoch 0.
# Saved check point for epoch 10.
# Saved check point for epoch 20.
# Saved check point for epoch 30.
# Saved check point for epoch 40.
# Saved check point for epoch 50.
# Saved check point for epoch 60.
# Saved check point for epoch 70.
# Saved check point for epoch 80.
# Saved check point for epoch 90.
#
# =========== EPOCH 100 COMPLETE ===========
# Obj: 5.73e+07
# ----------------------------------------
# NELL: 3.73e+07, 8.95e+06, 9.92e+06
# Latent KL: 2.09e+04, 5.92e+03, 6.15e+03
# LM KL: 3.85e+05, 1.63e+05, 2.26e+05
# Mn KL: 7.77e+04, 6.55e+04, 8.82e+04
# Psi KL: 3.47e+04, 3.63e+04, 4.00e+04
# ----------------------------------------
# LR: 0.01
# Elapsed time (secs): 38.4937424659729
# ----------------------------------------
# CPU cur memory used (GB): 2.73e+01
# GPU_0 cur memory used (GB): 4.08e-01, max memory used (GB): 4.08e-01
# Saved check point for epoch 100.
# Saved check point for epoch 110.
# Saved check point for epoch 120.
# Saved check point for epoch 130.
# Saved check point for epoch 140.
# Saved check point for epoch 150.
# Saved check point for epoch 160.
# Saved check point for epoch 170.
# Saved check point for epoch 180.
# Saved check point for epoch 190.
#
# =========== EPOCH 200 COMPLETE ===========
# Obj: 5.64e+07
# ----------------------------------------
# NELL: 3.68e+07, 8.70e+06, 9.53e+06
# Latent KL: 2.10e+04, 4.49e+03, 6.10e+03
# LM KL: 4.62e+05, 2.48e+05, 3.29e+05
# Mn KL: 5.42e+04, 3.61e+04, 5.21e+04
# Psi KL: 3.24e+04, 3.23e+04, 3.59e+04
# ----------------------------------------
# LR: 0.01
# Elapsed time (secs): 77.88017344474792
# ----------------------------------------
# CPU cur memory used (GB): 2.73e+01
# GPU_0 cur memory used (GB): 4.08e-01, max memory used (GB): 4.08e-01
# Saved check point for epoch 200.
# Saved check point for epoch 210.
# Saved check point for epoch 220.
# Saved check point for epoch 230.
# Saved check point for epoch 240.
# Saved check point for epoch 250.
# Saved check point for epoch 260.
# Saved check point for epoch 270.
# Saved check point for epoch 280.
# Saved check point for epoch 290.
#
# =========== EPOCH 300 COMPLETE ===========
# Obj: 5.59e+07
# ----------------------------------------
# NELL: 3.67e+07, 8.48e+06, 9.31e+06
# Latent KL: 2.13e+04, 5.80e+03, 6.22e+03
# LM KL: 5.00e+05, 3.06e+05, 3.85e+05
# Mn KL: 5.17e+04, 3.26e+04, 4.78e+04
# Psi KL: 3.15e+04, 2.99e+04, 3.35e+04
# ----------------------------------------
# LR: 0.001
# Elapsed time (secs): 117.12025213241577
# ----------------------------------------
# CPU cur memory used (GB): 2.73e+01
# GPU_0 cur memory used (GB): 4.08e-01, max memory used (GB): 4.08e-01
# Saved check point for epoch 300.
# Saved check point for epoch 310.
# Saved check point for epoch 320.
# Saved check point for epoch 330.
# Saved check point for epoch 340.
# Saved check point for epoch 350.
# Saved check point for epoch 360.
# Saved check point for epoch 370.
# Saved check point for epoch 380.
# Saved check point for epoch 390.
#
# =========== EPOCH 400 COMPLETE ===========
# Obj: 5.58e+07
# ----------------------------------------
# NELL: 3.67e+07, 8.46e+06, 9.27e+06
# Latent KL: 2.15e+04, 5.99e+03, 6.21e+03
# LM KL: 4.94e+05, 3.03e+05, 3.79e+05
# Mn KL: 4.93e+04, 3.02e+04, 4.45e+04
# Psi KL: 3.15e+04, 2.96e+04, 3.33e+04
# ----------------------------------------
# LR: 0.001
# Elapsed time (secs): 157.6095404624939
# ----------------------------------------
# CPU cur memory used (GB): 2.73e+01
# GPU_0 cur memory used (GB): 4.08e-01, max memory used (GB): 4.08e-01
# Saved check point for epoch 400.
# Saved check point for epoch 410.
# Saved check point for epoch 420.
# Saved check point for epoch 430.
# Saved check point for epoch 440.
# Saved check point for epoch 450.
# Saved check point for epoch 460.
# Saved check point for epoch 470.
# Saved check point for epoch 480.
# Saved check point for epoch 490.

# %% [markdown]
# ## Evaluate performance across check points on validation performance

# %%
cp_epochs, cp_elbo = evaluate_check_points(cp_folder=ps['cp_save_folder'], 
                              data=[torch.tensor(validation_data_conc[k]) for k in validation_data_conc.keys()], 
                              props=[neuron_locs[k] for k in neuron_locs.keys()], 
                              n_smps=1, device=devices[0])
# Out:
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.19e+07
# ----------------------------------------
# NELL: 1.19e+07
# Latent KL: 3.14e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.028397798538208008
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.71e+07
# ----------------------------------------
# NELL: 1.71e+07
# Latent KL: 1.99e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.028345346450805664
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.36e+07
# ----------------------------------------
# NELL: 2.36e+07
# Latent KL: 1.69e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.030519485473632812
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 330.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.16e+07
# ----------------------------------------
# NELL: 1.16e+07
# Latent KL: 3.00e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.028133630752563477
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.63e+07
# ----------------------------------------
# NELL: 1.63e+07
# Latent KL: 2.06e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02744913101196289
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.02e+07
# ----------------------------------------
# NELL: 2.02e+07
# Latent KL: 2.86e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02737903594970703
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 400.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.13e+07
# ----------------------------------------
# NELL: 1.13e+07
# Latent KL: 3.04e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027272462844848633
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.74e+07
# ----------------------------------------
# NELL: 1.74e+07
# Latent KL: 1.94e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027123689651489258
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.06e+07
# ----------------------------------------
# NELL: 2.06e+07
# Latent KL: 1.91e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027482271194458008
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 250.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.15e+07
# ----------------------------------------
# NELL: 1.15e+07
# Latent KL: 3.13e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027707576751708984
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.70e+07
# ----------------------------------------
# NELL: 1.70e+07
# Latent KL: 1.98e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027798175811767578
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.11e+07
# ----------------------------------------
# NELL: 2.11e+07
# Latent KL: 1.85e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027991533279418945
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 170.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.24e+07
# ----------------------------------------
# NELL: 1.24e+07
# Latent KL: 2.95e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.028077363967895508
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.50e+07
# ----------------------------------------
# NELL: 1.50e+07
# Latent KL: 1.97e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027661800384521484
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.07e+07
# ----------------------------------------
# NELL: 2.07e+07
# Latent KL: 1.33e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.029020309448242188
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 180.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.18e+07
# ----------------------------------------
# NELL: 1.18e+07
# Latent KL: 2.62e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02920699119567871
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.58e+07
# ----------------------------------------
# NELL: 1.58e+07
# Latent KL: 1.54e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027259349822998047
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.97e+07
# ----------------------------------------
# NELL: 1.97e+07
# Latent KL: 1.69e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025822162628173828
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 130.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.19e+07
# ----------------------------------------
# NELL: 1.19e+07
# Latent KL: 2.62e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027162790298461914
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.51e+07
# ----------------------------------------
# NELL: 1.51e+07
# Latent KL: 1.88e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02539372444152832
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.14e+07
# ----------------------------------------
# NELL: 2.14e+07
# Latent KL: 1.65e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02596759796142578
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 490.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.13e+07
# ----------------------------------------
# NELL: 1.13e+07
# Latent KL: 2.24e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026913166046142578
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.63e+07
# ----------------------------------------
# NELL: 1.63e+07
# Latent KL: 2.35e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025238990783691406
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.16e+07
# ----------------------------------------
# NELL: 2.16e+07
# Latent KL: 2.06e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025899648666381836
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 200.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.20e+07
# ----------------------------------------
# NELL: 1.20e+07
# Latent KL: 2.21e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02677130699157715
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.57e+07
# ----------------------------------------
# NELL: 1.57e+07
# Latent KL: 2.16e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025208711624145508
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.93e+07
# ----------------------------------------
# NELL: 1.93e+07
# Latent KL: 1.58e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025743722915649414
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 220.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.17e+07
# ----------------------------------------
# NELL: 1.17e+07
# Latent KL: 2.34e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02699136734008789
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.51e+07
# ----------------------------------------
# NELL: 1.51e+07
# Latent KL: 2.36e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02517557144165039
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.97e+07
# ----------------------------------------
# NELL: 1.97e+07
# Latent KL: 2.10e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025636911392211914
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 120.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.12e+07
# ----------------------------------------
# NELL: 1.12e+07
# Latent KL: 3.13e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026884794235229492
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.80e+07
# ----------------------------------------
# NELL: 1.80e+07
# Latent KL: 1.83e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02509784698486328
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.38e+07
# ----------------------------------------
# NELL: 2.38e+07
# Latent KL: 2.08e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025499582290649414
# ----------------------------------------
# CPU cur memory used (GB): 2.77e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 260.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.08e+07
# ----------------------------------------
# NELL: 1.08e+07
# Latent KL: 2.87e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02683115005493164
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.73e+07
# ----------------------------------------
# NELL: 1.73e+07
# Latent KL: 1.79e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02531147003173828
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.07e+07
# ----------------------------------------
# NELL: 2.07e+07
# Latent KL: 1.82e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025815725326538086
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 100.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.15e+07
# ----------------------------------------
# NELL: 1.15e+07
# Latent KL: 2.51e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02671194076538086
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.53e+07
# ----------------------------------------
# NELL: 1.53e+07
# Latent KL: 1.82e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02541065216064453
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.55e+07
# ----------------------------------------
# NELL: 2.55e+07
# Latent KL: 1.79e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025850534439086914
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 460.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.17e+07
# ----------------------------------------
# NELL: 1.17e+07
# Latent KL: 2.96e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026857852935791016
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.62e+07
# ----------------------------------------
# NELL: 1.62e+07
# Latent KL: 1.90e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025229215621948242
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.92e+07
# ----------------------------------------
# NELL: 1.92e+07
# Latent KL: 2.10e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025804996490478516
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 160.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.13e+07
# ----------------------------------------
# NELL: 1.13e+07
# Latent KL: 3.27e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02697896957397461
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.52e+07
# ----------------------------------------
# NELL: 1.52e+07
# Latent KL: 2.03e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025130271911621094
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.36e+07
# ----------------------------------------
# NELL: 2.36e+07
# Latent KL: 2.00e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.029623985290527344
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 110.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.19e+07
# ----------------------------------------
# NELL: 1.19e+07
# Latent KL: 2.95e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02699112892150879
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.60e+07
# ----------------------------------------
# NELL: 1.60e+07
# Latent KL: 1.49e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025376558303833008
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.35e+07
# ----------------------------------------
# NELL: 2.35e+07
# Latent KL: 1.66e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025867700576782227
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 280.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.17e+07
# ----------------------------------------
# NELL: 1.17e+07
# Latent KL: 3.08e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026694059371948242
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.51e+07
# ----------------------------------------
# NELL: 1.51e+07
# Latent KL: 1.84e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025221586227416992
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.25e+07
# ----------------------------------------
# NELL: 2.25e+07
# Latent KL: 2.14e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02582836151123047
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 480.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.18e+07
# ----------------------------------------
# NELL: 1.18e+07
# Latent KL: 3.28e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026716232299804688
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.55e+07
# ----------------------------------------
# NELL: 1.55e+07
# Latent KL: 1.92e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025318384170532227
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.87e+07
# ----------------------------------------
# NELL: 1.87e+07
# Latent KL: 2.04e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026106834411621094
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 30.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.10e+07
# ----------------------------------------
# NELL: 1.10e+07
# Latent KL: 3.03e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026761531829833984
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.64e+07
# ----------------------------------------
# NELL: 1.64e+07
# Latent KL: 2.20e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.028583049774169922
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.12e+07
# ----------------------------------------
# NELL: 2.12e+07
# Latent KL: 1.97e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027801513671875
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 90.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.16e+07
# ----------------------------------------
# NELL: 1.16e+07
# Latent KL: 2.63e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02735137939453125
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.65e+07
# ----------------------------------------
# NELL: 1.65e+07
# Latent KL: 2.01e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025281667709350586
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.25e+07
# ----------------------------------------
# NELL: 2.25e+07
# Latent KL: 1.71e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025851964950561523
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 370.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.26e+07
# ----------------------------------------
# NELL: 1.26e+07
# Latent KL: 2.68e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026639461517333984
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.67e+07
# ----------------------------------------
# NELL: 1.67e+07
# Latent KL: 2.01e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025289535522460938
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.38e+07
# ----------------------------------------
# NELL: 2.38e+07
# Latent KL: 2.35e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025886058807373047
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 340.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.14e+07
# ----------------------------------------
# NELL: 1.14e+07
# Latent KL: 2.90e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02696537971496582
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.54e+07
# ----------------------------------------
# NELL: 1.54e+07
# Latent KL: 1.63e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025359153747558594
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.04e+07
# ----------------------------------------
# NELL: 2.04e+07
# Latent KL: 1.57e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025945425033569336
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 190.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.15e+07
# ----------------------------------------
# NELL: 1.15e+07
# Latent KL: 3.13e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.0270235538482666
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.63e+07
# ----------------------------------------
# NELL: 1.63e+07
# Latent KL: 1.66e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02536463737487793
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.93e+07
# ----------------------------------------
# NELL: 1.93e+07
# Latent KL: 1.83e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025823354721069336
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 270.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.19e+07
# ----------------------------------------
# NELL: 1.19e+07
# Latent KL: 2.30e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026847124099731445
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.68e+07
# ----------------------------------------
# NELL: 1.68e+07
# Latent KL: 1.95e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02538299560546875
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.36e+07
# ----------------------------------------
# NELL: 2.36e+07
# Latent KL: 2.15e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025656700134277344
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 360.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.18e+07
# ----------------------------------------
# NELL: 1.18e+07
# Latent KL: 3.16e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.0266571044921875
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.85e+07
# ----------------------------------------
# NELL: 1.85e+07
# Latent KL: 2.03e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025304079055786133
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.51e+07
# ----------------------------------------
# NELL: 2.51e+07
# Latent KL: 1.42e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025706768035888672
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 410.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.16e+07
# ----------------------------------------
# NELL: 1.16e+07
# Latent KL: 2.94e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026677846908569336
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.70e+07
# ----------------------------------------
# NELL: 1.70e+07
# Latent KL: 2.20e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025149106979370117
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.30e+07
# ----------------------------------------
# NELL: 2.30e+07
# Latent KL: 1.72e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025805950164794922
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 320.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.18e+07
# ----------------------------------------
# NELL: 1.18e+07
# Latent KL: 3.00e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026792287826538086
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.74e+07
# ----------------------------------------
# NELL: 1.74e+07
# Latent KL: 2.07e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025233030319213867
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.34e+07
# ----------------------------------------
# NELL: 2.34e+07
# Latent KL: 1.63e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025744915008544922
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 310.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.21e+07
# ----------------------------------------
# NELL: 1.21e+07
# Latent KL: 2.79e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026780128479003906
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.77e+07
# ----------------------------------------
# NELL: 1.77e+07
# Latent KL: 2.08e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025542736053466797
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.17e+07
# ----------------------------------------
# NELL: 2.17e+07
# Latent KL: 2.15e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02623915672302246
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 300.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.16e+07
# ----------------------------------------
# NELL: 1.16e+07
# Latent KL: 4.06e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02664351463317871
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.58e+07
# ----------------------------------------
# NELL: 1.58e+07
# Latent KL: 2.58e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02519989013671875
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.26e+07
# ----------------------------------------
# NELL: 2.26e+07
# Latent KL: 1.59e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025705575942993164
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 80.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.22e+07
# ----------------------------------------
# NELL: 1.22e+07
# Latent KL: 2.93e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02694082260131836
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.69e+07
# ----------------------------------------
# NELL: 1.69e+07
# Latent KL: 1.81e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025501728057861328
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.34e+07
# ----------------------------------------
# NELL: 2.34e+07
# Latent KL: 1.87e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02588677406311035
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 390.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.12e+07
# ----------------------------------------
# NELL: 1.12e+07
# Latent KL: 2.61e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026714563369750977
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.74e+07
# ----------------------------------------
# NELL: 1.74e+07
# Latent KL: 2.08e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025119304656982422
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.59e+07
# ----------------------------------------
# NELL: 2.59e+07
# Latent KL: 1.73e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025538206100463867
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 450.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.14e+07
# ----------------------------------------
# NELL: 1.14e+07
# Latent KL: 2.77e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026539325714111328
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.69e+07
# ----------------------------------------
# NELL: 1.69e+07
# Latent KL: 2.24e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025139808654785156
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.36e+07
# ----------------------------------------
# NELL: 2.36e+07
# Latent KL: 2.30e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02563023567199707
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 50.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.18e+07
# ----------------------------------------
# NELL: 1.18e+07
# Latent KL: 1.99e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026529788970947266
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.57e+07
# ----------------------------------------
# NELL: 1.57e+07
# Latent KL: 2.30e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025126218795776367
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.84e+07
# ----------------------------------------
# NELL: 1.84e+07
# Latent KL: 2.17e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02570796012878418
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 150.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.16e+07
# ----------------------------------------
# NELL: 1.16e+07
# Latent KL: 3.15e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026559114456176758
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.53e+07
# ----------------------------------------
# NELL: 1.53e+07
# Latent KL: 1.73e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.024949073791503906
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.96e+07
# ----------------------------------------
# NELL: 1.96e+07
# Latent KL: 2.02e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025571584701538086
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 10.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.14e+07
# ----------------------------------------
# NELL: 1.14e+07
# Latent KL: 2.66e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026922941207885742
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.70e+07
# ----------------------------------------
# NELL: 1.70e+07
# Latent KL: 1.92e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02523970603942871
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.22e+07
# ----------------------------------------
# NELL: 2.22e+07
# Latent KL: 1.91e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025784730911254883
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 440.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.12e+07
# ----------------------------------------
# NELL: 1.12e+07
# Latent KL: 3.38e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026816368103027344
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.52e+07
# ----------------------------------------
# NELL: 1.52e+07
# Latent KL: 2.01e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025554656982421875
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.00e+07
# ----------------------------------------
# NELL: 2.00e+07
# Latent KL: 1.64e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026112794876098633
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 60.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.09e+07
# ----------------------------------------
# NELL: 1.09e+07
# Latent KL: 2.86e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026628494262695312
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.74e+07
# ----------------------------------------
# NELL: 1.74e+07
# Latent KL: 2.04e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025290727615356445
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.12e+07
# ----------------------------------------
# NELL: 2.12e+07
# Latent KL: 1.84e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02575826644897461
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 380.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.16e+07
# ----------------------------------------
# NELL: 1.16e+07
# Latent KL: 3.75e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02660846710205078
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# ...
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.34e+07
# ----------------------------------------
# NELL: 2.34e+07
# Latent KL: 1.77e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02560734748840332
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 420.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.16e+07
# ----------------------------------------
# NELL: 1.16e+07
# Latent KL: 2.38e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026630401611328125
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.57e+07
# ----------------------------------------
# NELL: 1.57e+07
# Latent KL: 2.18e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025101661682128906
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.28e+07
# ----------------------------------------
# NELL: 2.28e+07
# Latent KL: 2.63e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025663137435913086
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 470.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.11e+07
# ----------------------------------------
# NELL: 1.11e+07
# Latent KL: 3.00e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02654099464416504
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.63e+07
# ----------------------------------------
# NELL: 1.63e+07
# Latent KL: 1.63e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025060415267944336
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.30e+07
# ----------------------------------------
# NELL: 2.30e+07
# Latent KL: 1.96e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025582313537597656
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 350.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.13e+07
# ----------------------------------------
# NELL: 1.13e+07
# Latent KL: 2.59e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026881933212280273
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.61e+07
# ----------------------------------------
# NELL: 1.61e+07
# Latent KL: 2.45e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027776241302490234
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.26e+07
# ----------------------------------------
# NELL: 2.26e+07
# Latent KL: 2.02e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027133941650390625
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 0.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.15e+07
# ----------------------------------------
# NELL: 1.15e+07
# Latent KL: 3.39e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02699756622314453
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.73e+07
# ----------------------------------------
# NELL: 1.73e+07
# Latent KL: 2.41e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026538848876953125
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.95e+07
# ----------------------------------------
# NELL: 1.95e+07
# Latent KL: 1.88e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026764631271362305
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 290.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.12e+07
# ----------------------------------------
# NELL: 1.12e+07
# Latent KL: 3.17e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027383089065551758
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.54e+07
# ----------------------------------------
# NELL: 1.54e+07
# Latent KL: 1.61e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02542734146118164
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.04e+07
# ----------------------------------------
# NELL: 2.04e+07
# Latent KL: 1.96e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026707887649536133
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 20.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.16e+07
# ----------------------------------------
# NELL: 1.16e+07
# Latent KL: 2.06e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.027306079864501953
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.59e+07
# ----------------------------------------
# NELL: 1.59e+07
# Latent KL: 1.73e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026181697845458984
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.12e+07
# ----------------------------------------
# NELL: 2.12e+07
# Latent KL: 2.25e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02585577964782715
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 210.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.08e+07
# ----------------------------------------
# NELL: 1.08e+07
# Latent KL: 2.91e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026558876037597656
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.61e+07
# ----------------------------------------
# NELL: 1.61e+07
# Latent KL: 1.61e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025038719177246094
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.19e+07
# ----------------------------------------
# NELL: 2.19e+07
# Latent KL: 2.35e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025606870651245117
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 230.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.14e+07
# ----------------------------------------
# NELL: 1.14e+07
# Latent KL: 3.79e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026622772216796875
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.63e+07
# ----------------------------------------
# NELL: 1.63e+07
# Latent KL: 2.19e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02498483657836914
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.34e+07
# ----------------------------------------
# NELL: 2.34e+07
# Latent KL: 1.43e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.0254976749420166
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 430.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.09e+07
# ----------------------------------------
# NELL: 1.09e+07
# Latent KL: 2.72e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026582717895507812
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.63e+07
# ----------------------------------------
# NELL: 1.63e+07
# Latent KL: 1.85e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025030851364135742
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.13e+07
# ----------------------------------------
# NELL: 2.13e+07
# Latent KL: 2.09e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.0253603458404541
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 40.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.10e+07
# ----------------------------------------
# NELL: 1.10e+07
# Latent KL: 3.29e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026423215866088867
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.59e+07
# ----------------------------------------
# NELL: 1.59e+07
# Latent KL: 1.72e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025019407272338867
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.10e+07
# ----------------------------------------
# NELL: 2.10e+07
# Latent KL: 2.51e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025456666946411133
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 240.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.11e+07
# ----------------------------------------
# NELL: 1.11e+07
# Latent KL: 2.99e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02681422233581543
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.53e+07
# ----------------------------------------
# NELL: 1.53e+07
# Latent KL: 2.28e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02683115005493164
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.81e+07
# ----------------------------------------
# NELL: 1.81e+07
# Latent KL: 1.93e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02778458595275879
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 70.
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.14e+07
# ----------------------------------------
# NELL: 1.14e+07
# Latent KL: 2.37e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02772974967956543
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.52e-01, max memory used (GB): 3.52e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.64e+07
# ----------------------------------------
# NELL: 1.64e+07
# Latent KL: 2.00e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026960134506225586
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.70e-01, max memory used (GB): 3.70e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.06e+07
# ----------------------------------------
# NELL: 2.06e+07
# Latent KL: 1.60e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02772665023803711
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 4.00e-01, max memory used (GB): 4.00e-01
# Done with check point for epoch: 140.

# %% [markdown]
# ## View validation peformance as fitting continued

# %%
plt.figure()
plt.plot(cp_epochs, np.mean(cp_elbo, axis=1))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Pick the best ip model based on early stopping

# %%
if ps['use_early_stopping']:
    best_cp_epoch = cp_epochs[np.argmax(np.mean(cp_elbo, axis=1))].astype('int')
    print('Best epoch is ' + str(best_cp_epoch) + '.')

    best_cp = torch.load(Path(ps['cp_save_folder']) / ('cp_' + str(best_cp_epoch) + '.pt'))    
    ip_eval_vi_collections = [VICollection.from_checkpoint(coll_d) for coll_d in best_cp['vi_collections']]
    for c_i, coll in enumerate(ip_eval_vi_collections):
        coll.props = ip_vi_collections[c_i].props
    ip_eval_priors = PriorCollection.from_checkpoint(best_cp['priors'])
    
else:
    ip_eval_vi_collections = ip_vi_collections
    ip_eval_priors = ip_priors
    
ip_eval_posteriors = {s_n: ip_eval_vi_collections[s_i].posteriors for s_i, s_n in enumerate(subjects)}
# Out:
# Best epoch is 90.

# %% [markdown]
# ## Infer latents with the ip models for the validation data

# %%
ip_validation_latent_posts ={s_n: infer_latents(vi_collection=ip_eval_vi_collections[s_i],
                                                data=torch.tensor(validation_data_conc[s_n]),
                                                fit_opts={'n_epochs': 1000, 'init_lr':.1, 'update_int':500, 
                                                          'milestones': [500]}, 
                                                device=devices[0])[0]
                         for s_i, s_n in enumerate(subjects)}
# Out:
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.11e+07
# ----------------------------------------
# NELL: 1.11e+07
# Latent KL: 2.23e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.02709817886352539
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.67e-01, max memory used (GB): 3.67e-01
#
# =========== EPOCH 500 COMPLETE ===========
# Obj: 5.20e+06
# ----------------------------------------
# NELL: 5.20e+06
# Latent KL: 2.09e+03
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 12.720239162445068
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.67e-01, max memory used (GB): 3.67e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 1.71e+07
# ----------------------------------------
# NELL: 1.71e+07
# Latent KL: 1.68e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.025638341903686523
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.66e-01, max memory used (GB): 3.66e-01
#
# =========== EPOCH 500 COMPLETE ===========
# Obj: 3.73e+06
# ----------------------------------------
# NELL: 3.73e+06
# Latent KL: 1.57e+03
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 13.055537462234497
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.66e-01, max memory used (GB): 3.66e-01
#
# =========== EPOCH 0 COMPLETE ===========
# Obj: 2.25e+07
# ----------------------------------------
# NELL: 2.25e+07
# Latent KL: 2.09e+01
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.1
# Elapsed time (secs): 0.026526927947998047
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.75e-01, max memory used (GB): 3.75e-01
#
# =========== EPOCH 500 COMPLETE ===========
# Obj: 4.31e+06
# ----------------------------------------
# NELL: 4.31e+06
# Latent KL: 1.40e+03
# LM KL: 0.00e+00
# Mn KL: 0.00e+00
# Psi KL: 0.00e+00
# ----------------------------------------
# LR: 0.010000000000000002
# Elapsed time (secs): 12.832698583602905
# ----------------------------------------
# CPU cur memory used (GB): 2.76e+01
# GPU_0 cur memory used (GB): 3.75e-01, max memory used (GB): 3.75e-01

# %%
ip_fitter.distribute(devices=[torch.device('cpu')])

# %% [markdown]
# ## View fitting log for ip models

# %%
ip_fitter.plot_log(ip_log)
# Out:
# [True, True, True, True, True, True]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## View latents estimated with the ip models

# %%
ip_prior_lm_conc = ip_eval_priors.lm_prior(props_conc).detach().numpy()

# %%
view_validaton = True

# %%
ip_latents = dict()
if view_validaton:
    ip_view_latents_post = ip_validation_latent_posts
else:
    ip_view_latents_post = {k: ip_eval_posteriors[k].latent_post for k in ip_eval_posteriors.keys()}
    
for s_n, latent_post_n in ip_view_latents_post.items():

    latents_n = latent_post_n.mns.detach().numpy()
    _, latents_o = orthonormalize(ip_prior_lm_conc, latents_n, unit_len_columns=False )
        
    ip_latents[s_n] = {'latents': latents_n, 'latents_o': latents_o}

# %%
start_dim = 0

plt.figure()
ax = plt.axes(projection='3d')

for s_i, s_n in enumerate(sp_latents.keys()):
    plot_latents = ip_latents[s_n]['latents_o']
    if view_validaton:
        plot_labels = validation_labels_conc[s_n]
    else:
        plot_labels = fit_labels_conc[s_n]
    
    for sp, sp_lbl in label_map.items():
        sp_clr = subperiod_clrs[sp]
        sp_inds = plot_labels == sp_lbl
        ax.scatter(plot_latents[sp_inds,start_dim+0], plot_latents[sp_inds,start_dim+1], 
                   plot_latents[sp_inds,start_dim+2], color=sp_clr, marker=subject_markers[s_n])
    plt.title(str(s_n))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Visualize loading matrices across space for the ip models

# %%
vis_comp = 2

# %%
_, _, o_vis = svd(ip_prior_lm_conc, full_matrices=False)

mode_imgs = dict()
for s_n in subjects:
    neuron_locs_n = neuron_locs[s_n]
    
    lm_n = ip_eval_posteriors[s_n].lm_post(neuron_locs_n).detach().numpy()
    lm_n = np.matmul(lm_n, o_vis.transpose())
    
    mode_imgs[s_n], _ = max_project_pts(dot_positions=neuron_locs_n.numpy()[:,[0,1]].astype('float'),
                                        dot_vls=lm_n[:,vis_comp], 
                                        box_position=np.asarray([[0, 0], [990, 610]]), 
                                        n_divisions=np.asarray([990, 610]), 
                                        dot_dim_width=np.asarray([5,5]))
    
plt.figure()
cmp_n_mats([mode_imgs[k] for k in mode_imgs.keys()])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]
